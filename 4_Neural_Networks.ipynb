# %% [markdown]
# We work for CC: ConscientiousCars, where we help self-driving vehicles be more conscientious of their surroundings. Our cars have been very good at recognizing and avoiding humans. They haven't, however, been capable of recognizing dogs. Since dogs are man's best friend and will always be where we humans are, we want our cars to know if a dog is on the road in front of them and avoid the dog!
#
# The first step to avoiding these cute puppies is **knowing if a puppy is in front of the car**. So today we will **build a detector that can tell when our car sees a dog or not**!

# %%
#@title Run this to load some packages and data! { display-mode: "form" }
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from collections import Counter
import tensorflow.keras as keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore", category=UserWarning)


def categorical_to_numpy(labels_in):
  labels = []
  for label in labels_in:
    if label == 'dog':
      labels.append(np.array([1, 0]))
    else:
      labels.append(np.array([0, 1]))
  return np.array(labels)

def one_hot_encoding(input):
  output = np.array(input)
  output = np.zeros((input.size, input.max()+1))
  output[np.arange(input.size),input] = 1
  
  return output


def load_data():
  # Run this cell to download our data into a file called 'cifar_data'
  # !wget -O cifar_data https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%201%20-%205/Session%204%20_%205%20-%20Neural%20Networks%20_%20CNN/dogs_v_roads

  # now load the data from our cloud computer
  import pickle
  data_dict = pickle.load(open( "cifar_data", "rb" ));
  
  data   = data_dict['data']
  labels = data_dict['labels']
  
  return data, labels

def plot_one_image(data, labels, img_idx):
  from google.colab.patches import cv2_imshow
  import cv2
  import matplotlib.pyplot as plt
  my_img   = data[img_idx, :].squeeze().reshape([32,32,3]).copy()
  my_label = labels[img_idx]
  print('label: %s'%my_label)
  fig, ax = plt.subplots(1,1)

  img = ax.imshow(my_img, extent=[-1,1,-1,1])

  x_label_list = [0, 8, 16, 24, 32]
  y_label_list = [0, 8, 16, 24, 32]

  ax.set_xticks([-1, -0.5, 0, 0.5, 1])
  ax.set_yticks([-1, -0.5, 0, 0.5, 1])

  ax.set_xticklabels(x_label_list)
  ax.set_yticklabels(y_label_list)

  fig.show(img)
  
def CNNClassifier(num_epochs=30, layers=4, dropout=0.5):
  def create_model():
    model = Sequential()
    model.add(Reshape((32, 32, 3)))
    
    for i in range(layers):
      model.add(Conv2D(32, (3, 3), padding='same'))
      model.add(Activation('relu'))
    
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(dropout))
    model.add(Dense(2))
    model.add(Activation('softmax'))

    # initiate RMSprop optimizer
    opt = keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

    # Let's train the model using RMSprop
    model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    return model
  return KerasClassifier(build_fn=create_model, epochs=num_epochs, batch_size=10, verbose=2)

def plot_acc(history, ax = None, xlabel = 'Epoch #'):
    history = history.history
    history.update({'epoch':list(range(len(history['val_accuracy'])))})
    history = pd.DataFrame.from_dict(history)

    best_epoch = history.sort_values(by = 'val_accuracy', ascending = False).iloc[0]['epoch']

    if not ax:
      f, ax = plt.subplots(1,1)
    sns.lineplot(x = 'epoch', y = 'val_accuracy', data = history, label = 'Validation', ax = ax)
    sns.lineplot(x = 'epoch', y = 'accuracy', data = history, label = 'Training', ax = ax)
    ax.axhline(0.5, linestyle = '--',color='red', label = 'Chance')
    ax.axvline(x = best_epoch, linestyle = '--', color = 'green', label = 'Best Epoch')  
    ax.legend(loc = 7)    
    ax.set_ylim([0.4, 1])

    ax.set_xlabel(xlabel)
    ax.set_ylabel('Accuracy (Fraction)')
    
    plt.show()

# %% [markdown]
# In this notebook, you'll:
# - Explore the dogs vs. roads dataset
# - Train a simple K-neighbors classifier for computer vision
# - Train neural nets to tell dogs from roads
# - Improve your model with convolutional neural networks!
# - (Optional challenge) Use a saliency map to implement explainable AI

# %% [markdown]
# # Understanding our data

# %% [markdown]
# Our cars are very attentive and always have their eyes on the road.
#
# Every second, they're streaming in data about the street, including video.
#
# From this video data, we want our car to tell: is there 'road' or 'dog' in front of it?
#
# Lucky for us, we have a dataset of dog and road images already prepared! Let's start by reading that *labeled* data in.

# %%
# load our data 
data, labels = load_data()
# Out:
# --2022-10-09 20:50:14--  https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%201%20-%205/Session%204%20_%205%20-%20Neural%20Networks%20_%20CNN/dogs_v_roads
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.202.128, 74.125.199.128, 74.125.20.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.202.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3689015 (3.5M) [application/octet-stream]
# Saving to: ‘cifar_data’
#
# cifar_data          100%[===================>]   3.52M  --.-KB/s    in 0.02s
#
# 2022-10-09 20:50:14 (224 MB/s) - ‘cifar_data’ saved [3689015/3689015]

# %% [markdown]
# Let's look at an image of a dog!
#
# Try changing the number below. What does it do?

# %%
plot_one_image(data, labels, 1) #change this number
# Out:
# label: dog

# %% [markdown]
# **Discuss:** Why might we be using such blurry images?
#  - Answer: Resolution is 32x32 so less information to process so car can stop in time, and dog and road is very different so don't need to get into specifics
#
# Next, let's try a road image. Again, try changing the number:

# %%
plot_one_image(data, labels, 500) #change this number
# Out:
# label: road

# %% [markdown]
# How many images do we have?

# %%
print (len(data))
print(Counter(labels))
# Out:
# 1200
# Counter({'dog': 600, 'road': 600})

# %% [markdown]
# The dataset is organized such that there are 600 images of dogs and 600 images of roads.

# %% [markdown]
# #### Optional Exercise: Examining More Images
#
# **Look at a few more images of both classes.**
#
# Try using a `for` loop to look at 5 images!

# %%
### YOUR CODE HERE
from random import randint
for _ in range(5):
  plot_one_image(data, labels, randint(0, 599))
### END CODE
# Out:
# label: dog
# label: dog
# label: dog
# label: road
# label: dog

# %% [markdown]
# ##Understanding our Data Representation
#
# In an image each pixel is denoted by 3 numbers that represent the intensity value of that pixel (0 - 255) for each color channel (R, G, and B). Below we
# see a list of numbers for each image that represent the intensity values.

# %%
print('One image looks like: ')
print(data[0])
print("Length of list: ", len(data[0]))
# Out:
# One image looks like:
# [45 20 19 ... 83 99 31]
# Length of list:  3072

# %% [markdown]
# **Discuss:** What does each number mean? Can you explain the length of the list?

# %%
#@title Exercise: Fill in the correct values for each image's height, width, and number of color channels:

img_height =  32#@param {type:"integer"}
img_width =  32#@param {type:"integer"}
color_channels =  3#@param {type:"integer"}

if img_height == 32 and img_width == 32 and color_channels == 3:
  print("Correct!")
  print ("Each image is", img_height, 'x', img_width, 'pixels.')
  print ("Each pixel has", color_channels, "channels for red, green, blue.")
  print ("This gives a total of", img_height * img_width * color_channels, "intensity values per image.")
else:
  print("Those aren't quite the values.")
  print("Your values give a total of", img_height * img_width * color_channels, "intensity values per image.") 
  print("Discuss with your group and try again!")
# Out:
# Correct!
# Each image is 32 x 32 pixels.
# Each pixel has 3 channels for red, green, blue.
# This gives a total of 3072 intensity values per image.

# %% [markdown]
# We use these values as **inputs** to predict an **output** label: 'dog' or 'road'!
#
# Here's what our entire dataset looks like:

# %%
print ('Data shape:', data.shape)
print ('Data:', data)
# Out:
# Data shape: (1200, 3072)
# Data: [[ 45  20  19 ...  83  99  31]
#  [101 114  35 ... 155 134  91]
#  [213 221 221 ... 139  58  47]
#  ...
#  [126 174 202 ... 124 128 129]
#  [191 232 240 ...  74  93  81]
#  [237 248 254 ...  45  56  10]]

# %% [markdown]
# #A Simple Machine Learner

# %% [markdown]
# We want to create a machine learning model that can tell us whether a new image is either a dog or a road.
#
# We will give our model a training manual of data and labels that it will study or train on.
#
# We then check how well our model is doing on a test, where it is given data and told to predict their labels.

# %% [markdown]
# ##Building a KNN##

# %% [markdown]
# Let's start by using the `KNeighborsClassifier` model.
#
# **Playground:** Explore [this demo](http://vision.stanford.edu/teaching/cs231n-demos/knn/) to understand what the KNN model is doing!
#
# **Exercise:** Below, please build, train, and measure the accuracy of your own KNN model. Experiment with changing the number of neighbors!

# %%
# Preparing data and create training and test inputs and labels
X_train, X_test, y_train, y_test = model_selection.train_test_split(data, labels, test_size=0.2, random_state =1)

### YOUR CODE HERE

# Initialize our model
knn_model = KNeighborsClassifier(n_neighbors=3)

# Train our model
knn_model.fit(X_train, y_train)
# Test our model
y_pred = knn_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
# Print the score on the testing data
print(accuracy)
### END CODE
# Out:
# 0.8

# %% [markdown]
# **(Optional):** After you've built your KNN model, remove ```random_state=1``` and re-run the cells above. How does removing ```random_state=1``` affect your accuracy? Why?

# %% [markdown]
# ##Predicting on images
#
# We can use our trained model to predict whether our car is seeing a `dog` or `road`. Let's try this out - experiment with different images!

# %%
# Specify which image you want to show
image_id = 123 #Change this!

# Visualize the image
plot_one_image(X_test, y_test, image_id)

# Use the model to predict what this might be and print it
print('prediction:', knn_model.predict([X_test[image_id]])[0])
# Out:
# label: dog
# prediction: road

# %% [markdown]
# ## Choosing a value of k
#
# **Exercise** Determine the optimal value of "K" for our data. Use a for-loop to loop through different values of "K". In particular, *at the very least* try K = 1, 3, 5, 10, 20, and 30. For each of these values of "K", define a new KNN model, train it, and evaluate the accuracy.

# %%
### YOUR CODE HERE
# Preparing data and create training and test inputs and labels
X_train, X_test, y_train, y_test = model_selection.train_test_split(data, labels, test_size=0.2, random_state =1)

# Initialize our model
knn_model = KNeighborsClassifier(n_neighbors=3)

# Train our model
knn_model.fit(X_train, y_train)
# Test our model
y_pred = knn_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
# Print the score on the testing data
print(accuracy)
### END CODE
# Out:
# 0.8

# %% [markdown]
# **Discuss:** What are the advantages and disadvantages of using a bigger vs. smaller **k**? What is the optimal value?

# %% [markdown]
# ## (Optional) Understanding our mistakes
#
# Our classifications are OK, but are they good enough for our conscientious cars?
#
# Let's put on our detective hats to determine the root causes of the incorrect classifications!
#
# **Exercise:** Below, please print out 4 images of true positives, 4 images of true negatives, 4 images of false positives, and 4 images of false negatives. What are the reasons for failure (both for false positives and false negatives)?

# %%
#True Positives (code provided)
tp_count = 0
print ("TRUE POSITIVES")
i = 0
while tp_count < 4 and i < len(X_test):
  prediction = knn_model.predict([X_test[i]])[0] 
  if prediction == y_test[i] and prediction == 'dog':
    plot_one_image(X_test, y_test, i)
    tp_count += 1
  i += 1

#False Positives
fp_count = 0
print ("FALSE POSITIVES")
i = 0
while fp_count < 4 and i < len(X_test):
  prediction = knn_model.predict([X_test[i]])[0] 
  if prediction != y_test[i] and prediction == 'dog':
    plot_one_image(X_test, y_test, i)
    fp_count += 1
  i += 1

#True Negatives
tn_count = 0
print ("TRUE NEGATIVES")
i = 0
while tn_count < 4 and i < len(X_test):
  prediction = knn_model.predict([X_test[i]])[0] 
  if prediction == y_test[i] and prediction == 'road':
    plot_one_image(X_test, y_test, i)
    tn_count += 1
  i += 1

#False Negatives
fn_count = 0
print ("FALSE NEGATIVES")
i = 0
while fn_count < 4 and i < len(X_test):
  prediction = knn_model.predict([X_test[i]])[0] 
  if prediction != y_test[i] and prediction == 'road':
    plot_one_image(X_test, y_test, i)
    fn_count += 1
  i += 1
# Out:
# TRUE POSITIVES
# label: dog
# label: dog
# label: dog
# label: dog
# FALSE POSITIVES
# label: road
# label: road
# label: road
# TRUE NEGATIVES
# label: road
# label: road
# label: road
# label: road
# FALSE NEGATIVES
# label: dog
# label: dog
# label: dog
# label: dog

# %% [markdown]
# **Discuss:** What patterns did you notice? What are some reasons that the model makes mistakes?

# %% [markdown]
# #Neural Networks
# Now, let's create some new models using neural networks!
#
# You can play around with [TensorFlow Playground](https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.62283&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false&regularization_hide=true&regularizationRate_hide=true&learningRate_hide=true&batchSize_hide=true&stepButton_hide=true&activation_hide=true) to get a feel for how neural nets work.

# %% [markdown]
# To build a simple neural network, we use `MLPClassifier` from scikit-learn. We will play with the **number of neurons** and the **number of hidden layers** to adjust the complexity of our model, just like we did in Playground!
#
# **Example 1:**
# Here's how we create a neural network with 1 hidden layer of 3 neurons.
#
# `nnet = MLPClassifier(hidden_layer_sizes=(3)) `
#
# **Example 2:**
#
# Here's how we create a neural network with 2 hidden layers: one of 3 neurons and one of 4 neurons.
#
# `nnet = MLPClassifier(hidden_layer_sizes=(3, 4)) `
#
# **Discuss:** How might you build a neural network with 3 hidden layers? Run the code below and modify it!

# %%
# Create and train our multi layer perceptron model
nnet = MLPClassifier(hidden_layer_sizes=(100), random_state=1, max_iter=10000000)  ## How many hidden layers? How many neurons does this have?
nnet.fit(X_train, y_train)

# Predict what the classes are based on the testing data
predictions = nnet.predict(X_test)

# Print the score on the testing data
print("MLP Testing Accuracy:")
print(accuracy_score(y_test, predictions)*100)
# Out:
# MLP Testing Accuracy:
# 88.33333333333333

# %% [markdown]
# **How well did your neural network perform?**
#
# Multilayer perceptrons are more complex models and it can be difficult to find the right "settings" for them. It takes some trial and error!

# %% [markdown]
# **Exercise: try the following out and see how well you can get your network to do!**
# * Train a 1 layer, 10 neuron network for practice
# * Change the number of neurons and/or add layers to see how well you can do
# * Increase or decrease the number of iterations

# %%
#YOUR CODE HERE

# %% [markdown]
# ###Automating our Experiments
#
# **Exercise:** Similar to what you did for KNNs, use a for loop to automate your investigation. Explore different numbers of hidden layers, the size of the hidden layers, and the number of iterations! How well can you get your network performing?

# %%
### YOUR CODE HERE
from random import randint

trials = []
for _ in range(5):
  temp = ((randint(100, 200)), (randint(0, 100)))
  trials.append(temp)

# Create and train our multi layer perceptron model
for t in trials:
  nnet = MLPClassifier(hidden_layer_sizes=t, random_state=1, max_iter=10000000)  ## How many hidden layers? How many neurons does this have?
  nnet.fit(X_train, y_train)

  # Predict what the classes are based on the testing data
  predictions = nnet.predict(X_test)

  #Print the hidden layers
  print("Hidden layers and neurons:")
  print(t)

  # Print the score on the testing data
  print("MLP Testing Accuracy:")
  print(accuracy_score(y_test, predictions)*100)
### END CODE
# Out:
# Hidden layers and neurons:
# (121, 75)
# MLP Testing Accuracy:
# 91.66666666666666
# Hidden layers and neurons:
# (115, 54)
# MLP Testing Accuracy:
# 92.08333333333333
# Hidden layers and neurons:
# (104, 1)
# MLP Testing Accuracy:
# 52.916666666666664
# Hidden layers and neurons:
# (126, 53)
# MLP Testing Accuracy:
# 88.75
# Hidden layers and neurons:
# (173, 17)
# MLP Testing Accuracy:
# 80.83333333333333

# %% [markdown]
# # Models for Vision: Convolutional Neural Networks
# There is a famous type of neural network known as convolutional neural networks (CNNs). These types of neural networks work particularly well on problems to do with computer vision. Let's try one out!

# %% [markdown]
# ###Training Your CNN
# To load up a simple CNN on scikit-learn, just run:
#
# `cnn = CNNClassifier(num_epochs=N)`
#
# The `num_epochs` represents how many times the neural network passes through the training dataset.
#
# We'll need to change our data to floats (decimal numbers).
#
# **Exercise:** Please train and test your CNN below!

# %%
# convert our data to floats for our CNN
X_train = X_train.astype(float)
X_test = X_test.astype(float)

### YOUR CODE HERE
# Create and train our cnn
cnn = CNNClassifier(num_epochs=30)
cnn.fit(X_train, y_train)
# Predict what the classes are based on the testing data
y_pred = cnn.predict(X_test)
# Print the score on the testing data
print("CNN Testing Accuracy:")
print(accuracy_score(y_test, y_pred)*100)

### END CODE
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:111: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# 96/96 - 4s - loss: 1.1796 - accuracy: 0.6510 - 4s/epoch - 39ms/step
# Epoch 2/30
# 96/96 - 0s - loss: 0.4189 - accuracy: 0.8281 - 483ms/epoch - 5ms/step
# Epoch 3/30
# 96/96 - 0s - loss: 0.3404 - accuracy: 0.8635 - 475ms/epoch - 5ms/step
# Epoch 4/30
# 96/96 - 0s - loss: 0.2679 - accuracy: 0.8958 - 483ms/epoch - 5ms/step
# Epoch 5/30
# 96/96 - 0s - loss: 0.2400 - accuracy: 0.9042 - 493ms/epoch - 5ms/step
# Epoch 6/30
# 96/96 - 0s - loss: 0.2371 - accuracy: 0.9115 - 477ms/epoch - 5ms/step
# Epoch 7/30
# 96/96 - 0s - loss: 0.1884 - accuracy: 0.9260 - 484ms/epoch - 5ms/step
# Epoch 8/30
# 96/96 - 0s - loss: 0.1954 - accuracy: 0.9281 - 476ms/epoch - 5ms/step
# Epoch 9/30
# 96/96 - 1s - loss: 0.1647 - accuracy: 0.9333 - 503ms/epoch - 5ms/step
# Epoch 10/30
# 96/96 - 0s - loss: 0.1707 - accuracy: 0.9333 - 487ms/epoch - 5ms/step
# Epoch 11/30
# 96/96 - 1s - loss: 0.1720 - accuracy: 0.9448 - 507ms/epoch - 5ms/step
# Epoch 12/30
# 96/96 - 0s - loss: 0.1354 - accuracy: 0.9479 - 476ms/epoch - 5ms/step
# Epoch 13/30
# 96/96 - 0s - loss: 0.1529 - accuracy: 0.9427 - 478ms/epoch - 5ms/step
# Epoch 14/30
# 96/96 - 0s - loss: 0.1532 - accuracy: 0.9469 - 475ms/epoch - 5ms/step
# Epoch 15/30
# 96/96 - 0s - loss: 0.1233 - accuracy: 0.9500 - 482ms/epoch - 5ms/step
# Epoch 16/30
# 96/96 - 0s - loss: 0.1152 - accuracy: 0.9583 - 482ms/epoch - 5ms/step
# Epoch 17/30
# 96/96 - 0s - loss: 0.1080 - accuracy: 0.9615 - 484ms/epoch - 5ms/step
# Epoch 18/30
# 96/96 - 0s - loss: 0.1057 - accuracy: 0.9635 - 496ms/epoch - 5ms/step
# Epoch 19/30
# 96/96 - 0s - loss: 0.0960 - accuracy: 0.9656 - 487ms/epoch - 5ms/step
# Epoch 20/30
# 96/96 - 0s - loss: 0.0923 - accuracy: 0.9604 - 486ms/epoch - 5ms/step
# Epoch 21/30
# 96/96 - 0s - loss: 0.1012 - accuracy: 0.9635 - 476ms/epoch - 5ms/step
# Epoch 22/30
# 96/96 - 0s - loss: 0.0917 - accuracy: 0.9698 - 495ms/epoch - 5ms/step
# Epoch 23/30
# 96/96 - 0s - loss: 0.0981 - accuracy: 0.9708 - 479ms/epoch - 5ms/step
# Epoch 24/30
# 96/96 - 0s - loss: 0.0809 - accuracy: 0.9781 - 482ms/epoch - 5ms/step
# Epoch 25/30
# 96/96 - 0s - loss: 0.1055 - accuracy: 0.9677 - 479ms/epoch - 5ms/step
# Epoch 26/30
# 96/96 - 0s - loss: 0.0803 - accuracy: 0.9729 - 492ms/epoch - 5ms/step
# Epoch 27/30
# 96/96 - 0s - loss: 0.0900 - accuracy: 0.9750 - 481ms/epoch - 5ms/step
# Epoch 28/30
# 96/96 - 0s - loss: 0.0817 - accuracy: 0.9688 - 496ms/epoch - 5ms/step
# Epoch 29/30
# 96/96 - 0s - loss: 0.0671 - accuracy: 0.9750 - 479ms/epoch - 5ms/step
# Epoch 30/30
# 96/96 - 0s - loss: 0.0938 - accuracy: 0.9729 - 478ms/epoch - 5ms/step
# CNN Testing Accuracy:
# 96.66666666666667

# %% [markdown]
# **Discuss: Is this CNN good enough to use in practice?**
#
# CNNs typically perform better than basic Neural Networks on vision problems - but like basic Neural Networks, they aren't always consistent in their results and are sensitive to a number of factors.
#
# If you're interested in learning more about CNNs, spend some time exploring the [CNN Explainer](https://poloclub.github.io/cnn-explainer/)!
#
# **Report to the class your highest model accuracy.**
#
# **Bonus Question:** Each of you might see a different max accuracy. Can you think of why that might be?

# %% [markdown]
# ## Training and Validation Curves
#
# An important aspect of training neural networks is to prevent overfitting. **How do you know when your model is overfitting?**
#
# To plot our model's history, we can train it with
# ```
# history = model.fit(X_train, categorical_to_numpy(y_train), validation_data=(X_test, categorical_to_numpy(y_test)))
# ```
#
# and then use
# ```
# plot_acc(history)
# ```
# Don't forget to change ```model``` to be the name of your model!

# %% [markdown]
# **Exercise:** Train a CNN model and plot a train vs. test curve.
#
# **After how many epochs does the model begin to overfit?** Overfitting occurs when the validation accuracy starts to drop below the training accuracy.

# %%
# Create and train our cnn
cnn = CNNClassifier(num_epochs=200)

# Plot train vs test curve
history = cnn.fit(X_train, categorical_to_numpy(y_train), validation_data=(X_test, categorical_to_numpy(y_test)))
plot_acc(history)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:111: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# 96/96 - 2s - loss: 2.1555 - accuracy: 0.5958 - val_loss: 0.6029 - val_accuracy: 0.6458 - 2s/epoch - 19ms/step
# Epoch 2/200
# 96/96 - 1s - loss: 0.5806 - accuracy: 0.7635 - val_loss: 0.3427 - val_accuracy: 0.8542 - 547ms/epoch - 6ms/step
# Epoch 3/200
# 96/96 - 1s - loss: 0.3904 - accuracy: 0.8323 - val_loss: 0.2076 - val_accuracy: 0.9250 - 641ms/epoch - 7ms/step
# Epoch 4/200
# 96/96 - 1s - loss: 0.3133 - accuracy: 0.8656 - val_loss: 0.2673 - val_accuracy: 0.8917 - 549ms/epoch - 6ms/step
# Epoch 5/200
# 96/96 - 1s - loss: 0.2673 - accuracy: 0.9052 - val_loss: 0.1443 - val_accuracy: 0.9667 - 563ms/epoch - 6ms/step
# Epoch 6/200
# 96/96 - 1s - loss: 0.2423 - accuracy: 0.9094 - val_loss: 0.1790 - val_accuracy: 0.9167 - 546ms/epoch - 6ms/step
# Epoch 7/200
# 96/96 - 1s - loss: 0.2228 - accuracy: 0.9167 - val_loss: 0.1325 - val_accuracy: 0.9542 - 551ms/epoch - 6ms/step
# Epoch 8/200
# 96/96 - 1s - loss: 0.2134 - accuracy: 0.9208 - val_loss: 0.1152 - val_accuracy: 0.9625 - 545ms/epoch - 6ms/step
# Epoch 9/200
# 96/96 - 1s - loss: 0.1707 - accuracy: 0.9344 - val_loss: 0.1336 - val_accuracy: 0.9625 - 562ms/epoch - 6ms/step
# Epoch 10/200
# 96/96 - 1s - loss: 0.1597 - accuracy: 0.9365 - val_loss: 0.1195 - val_accuracy: 0.9625 - 543ms/epoch - 6ms/step
# Epoch 11/200
# 96/96 - 1s - loss: 0.1441 - accuracy: 0.9521 - val_loss: 0.1805 - val_accuracy: 0.9375 - 549ms/epoch - 6ms/step
# Epoch 12/200
# 96/96 - 1s - loss: 0.1303 - accuracy: 0.9563 - val_loss: 0.1011 - val_accuracy: 0.9625 - 556ms/epoch - 6ms/step
# Epoch 13/200
# 96/96 - 1s - loss: 0.1237 - accuracy: 0.9583 - val_loss: 0.1336 - val_accuracy: 0.9667 - 538ms/epoch - 6ms/step
# Epoch 14/200
# 96/96 - 1s - loss: 0.1465 - accuracy: 0.9438 - val_loss: 0.1154 - val_accuracy: 0.9583 - 574ms/epoch - 6ms/step
# Epoch 15/200
# 96/96 - 1s - loss: 0.1448 - accuracy: 0.9521 - val_loss: 0.1526 - val_accuracy: 0.9542 - 544ms/epoch - 6ms/step
# Epoch 16/200
# 96/96 - 1s - loss: 0.1173 - accuracy: 0.9677 - val_loss: 0.1256 - val_accuracy: 0.9708 - 545ms/epoch - 6ms/step
# Epoch 17/200
# 96/96 - 1s - loss: 0.1080 - accuracy: 0.9604 - val_loss: 0.1242 - val_accuracy: 0.9625 - 556ms/epoch - 6ms/step
# Epoch 18/200
# 96/96 - 1s - loss: 0.1064 - accuracy: 0.9625 - val_loss: 0.1192 - val_accuracy: 0.9708 - 549ms/epoch - 6ms/step
# Epoch 19/200
# 96/96 - 1s - loss: 0.0974 - accuracy: 0.9677 - val_loss: 0.1530 - val_accuracy: 0.9625 - 576ms/epoch - 6ms/step
# Epoch 20/200
# 96/96 - 1s - loss: 0.0853 - accuracy: 0.9719 - val_loss: 0.1259 - val_accuracy: 0.9708 - 559ms/epoch - 6ms/step
# Epoch 21/200
# 96/96 - 1s - loss: 0.0996 - accuracy: 0.9677 - val_loss: 0.1233 - val_accuracy: 0.9667 - 550ms/epoch - 6ms/step
# Epoch 22/200
# 96/96 - 1s - loss: 0.0988 - accuracy: 0.9646 - val_loss: 0.1138 - val_accuracy: 0.9708 - 542ms/epoch - 6ms/step
# Epoch 23/200
# 96/96 - 1s - loss: 0.0973 - accuracy: 0.9635 - val_loss: 0.1779 - val_accuracy: 0.9417 - 554ms/epoch - 6ms/step
# Epoch 24/200
# 96/96 - 1s - loss: 0.0782 - accuracy: 0.9646 - val_loss: 0.1313 - val_accuracy: 0.9667 - 545ms/epoch - 6ms/step
# Epoch 25/200
# 96/96 - 1s - loss: 0.0723 - accuracy: 0.9802 - val_loss: 0.1760 - val_accuracy: 0.9708 - 563ms/epoch - 6ms/step
# Epoch 26/200
# 96/96 - 1s - loss: 0.0650 - accuracy: 0.9792 - val_loss: 0.1373 - val_accuracy: 0.9708 - 539ms/epoch - 6ms/step
# Epoch 27/200
# 96/96 - 1s - loss: 0.0756 - accuracy: 0.9771 - val_loss: 0.1154 - val_accuracy: 0.9708 - 556ms/epoch - 6ms/step
# Epoch 28/200
# 96/96 - 1s - loss: 0.0643 - accuracy: 0.9812 - val_loss: 0.1321 - val_accuracy: 0.9708 - 556ms/epoch - 6ms/step
# Epoch 29/200
# 96/96 - 1s - loss: 0.0477 - accuracy: 0.9823 - val_loss: 0.1602 - val_accuracy: 0.9708 - 559ms/epoch - 6ms/step
# Epoch 30/200
# 96/96 - 1s - loss: 0.0783 - accuracy: 0.9771 - val_loss: 0.1487 - val_accuracy: 0.9708 - 539ms/epoch - 6ms/step
# Epoch 31/200
# 96/96 - 1s - loss: 0.0634 - accuracy: 0.9771 - val_loss: 0.1992 - val_accuracy: 0.9750 - 550ms/epoch - 6ms/step
# Epoch 32/200
# 96/96 - 1s - loss: 0.0497 - accuracy: 0.9812 - val_loss: 0.2574 - val_accuracy: 0.9250 - 566ms/epoch - 6ms/step
# Epoch 33/200
# 96/96 - 1s - loss: 0.0588 - accuracy: 0.9865 - val_loss: 0.1373 - val_accuracy: 0.9750 - 553ms/epoch - 6ms/step
# Epoch 34/200
# 96/96 - 1s - loss: 0.0551 - accuracy: 0.9792 - val_loss: 0.1552 - val_accuracy: 0.9667 - 580ms/epoch - 6ms/step
# Epoch 35/200
# 96/96 - 1s - loss: 0.0561 - accuracy: 0.9823 - val_loss: 0.1428 - val_accuracy: 0.9750 - 536ms/epoch - 6ms/step
# Epoch 36/200
# 96/96 - 1s - loss: 0.0390 - accuracy: 0.9896 - val_loss: 0.2033 - val_accuracy: 0.9625 - 547ms/epoch - 6ms/step
# Epoch 37/200
# 96/96 - 1s - loss: 0.0470 - accuracy: 0.9896 - val_loss: 0.1776 - val_accuracy: 0.9708 - 560ms/epoch - 6ms/step
# Epoch 38/200
# 96/96 - 1s - loss: 0.0555 - accuracy: 0.9865 - val_loss: 0.1799 - val_accuracy: 0.9625 - 549ms/epoch - 6ms/step
# Epoch 39/200
# 96/96 - 1s - loss: 0.0429 - accuracy: 0.9833 - val_loss: 0.1861 - val_accuracy: 0.9667 - 541ms/epoch - 6ms/step
# Epoch 40/200
# 96/96 - 1s - loss: 0.0586 - accuracy: 0.9833 - val_loss: 0.1446 - val_accuracy: 0.9708 - 547ms/epoch - 6ms/step
# Epoch 41/200
# 96/96 - 1s - loss: 0.0228 - accuracy: 0.9958 - val_loss: 0.2055 - val_accuracy: 0.9792 - 543ms/epoch - 6ms/step
# Epoch 42/200
# 96/96 - 1s - loss: 0.0488 - accuracy: 0.9854 - val_loss: 0.1698 - val_accuracy: 0.9750 - 572ms/epoch - 6ms/step
# Epoch 43/200
# 96/96 - 1s - loss: 0.0563 - accuracy: 0.9812 - val_loss: 0.1825 - val_accuracy: 0.9750 - 557ms/epoch - 6ms/step
# Epoch 44/200
# 96/96 - 1s - loss: 0.0280 - accuracy: 0.9927 - val_loss: 0.1714 - val_accuracy: 0.9750 - 537ms/epoch - 6ms/step
# Epoch 45/200
# 96/96 - 1s - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.1944 - val_accuracy: 0.9750 - 562ms/epoch - 6ms/step
# Epoch 46/200
# 96/96 - 1s - loss: 0.0365 - accuracy: 0.9927 - val_loss: 0.1646 - val_accuracy: 0.9750 - 553ms/epoch - 6ms/step
# Epoch 47/200
# 96/96 - 1s - loss: 0.0230 - accuracy: 0.9917 - val_loss: 0.1764 - val_accuracy: 0.9750 - 545ms/epoch - 6ms/step
# Epoch 48/200
# 96/96 - 1s - loss: 0.0353 - accuracy: 0.9865 - val_loss: 0.1695 - val_accuracy: 0.9792 - 552ms/epoch - 6ms/step
# Epoch 49/200
# 96/96 - 1s - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.2491 - val_accuracy: 0.9542 - 551ms/epoch - 6ms/step
# Epoch 50/200
# 96/96 - 1s - loss: 0.0376 - accuracy: 0.9896 - val_loss: 0.1756 - val_accuracy: 0.9750 - 551ms/epoch - 6ms/step
# Epoch 51/200
# 96/96 - 1s - loss: 0.0189 - accuracy: 0.9948 - val_loss: 0.2033 - val_accuracy: 0.9708 - 565ms/epoch - 6ms/step
# Epoch 52/200
# 96/96 - 1s - loss: 0.0510 - accuracy: 0.9885 - val_loss: 0.1939 - val_accuracy: 0.9833 - 554ms/epoch - 6ms/step
# Epoch 53/200
# 96/96 - 1s - loss: 0.0444 - accuracy: 0.9917 - val_loss: 0.2204 - val_accuracy: 0.9750 - 560ms/epoch - 6ms/step
# Epoch 54/200
# 96/96 - 1s - loss: 0.0444 - accuracy: 0.9896 - val_loss: 0.3355 - val_accuracy: 0.9500 - 554ms/epoch - 6ms/step
# Epoch 55/200
# 96/96 - 1s - loss: 0.0348 - accuracy: 0.9917 - val_loss: 0.2123 - val_accuracy: 0.9750 - 544ms/epoch - 6ms/step
# Epoch 56/200
# 96/96 - 1s - loss: 0.0561 - accuracy: 0.9865 - val_loss: 0.2164 - val_accuracy: 0.9750 - 549ms/epoch - 6ms/step
# Epoch 57/200
# 96/96 - 1s - loss: 0.0172 - accuracy: 0.9979 - val_loss: 0.2196 - val_accuracy: 0.9708 - 558ms/epoch - 6ms/step
# Epoch 58/200
# 96/96 - 1s - loss: 0.0268 - accuracy: 0.9906 - val_loss: 0.2455 - val_accuracy: 0.9708 - 548ms/epoch - 6ms/step
# Epoch 59/200
# 96/96 - 1s - loss: 0.0274 - accuracy: 0.9937 - val_loss: 0.2793 - val_accuracy: 0.9625 - 548ms/epoch - 6ms/step
# Epoch 60/200
# 96/96 - 1s - loss: 0.0482 - accuracy: 0.9865 - val_loss: 0.2561 - val_accuracy: 0.9750 - 556ms/epoch - 6ms/step
# Epoch 61/200
# 96/96 - 1s - loss: 0.0258 - accuracy: 0.9896 - val_loss: 0.2332 - val_accuracy: 0.9750 - 559ms/epoch - 6ms/step
# Epoch 62/200
# 96/96 - 1s - loss: 0.0521 - accuracy: 0.9896 - val_loss: 0.2037 - val_accuracy: 0.9708 - 542ms/epoch - 6ms/step
# Epoch 63/200
# 96/96 - 1s - loss: 0.0199 - accuracy: 0.9927 - val_loss: 0.2756 - val_accuracy: 0.9750 - 547ms/epoch - 6ms/step
# Epoch 64/200
# 96/96 - 1s - loss: 0.0227 - accuracy: 0.9948 - val_loss: 0.2664 - val_accuracy: 0.9625 - 544ms/epoch - 6ms/step
# Epoch 65/200
# 96/96 - 1s - loss: 0.0332 - accuracy: 0.9948 - val_loss: 0.2084 - val_accuracy: 0.9750 - 549ms/epoch - 6ms/step
# Epoch 66/200
# 96/96 - 1s - loss: 0.0327 - accuracy: 0.9917 - val_loss: 0.2840 - val_accuracy: 0.9667 - 536ms/epoch - 6ms/step
# Epoch 67/200
# 96/96 - 1s - loss: 0.0312 - accuracy: 0.9948 - val_loss: 0.3179 - val_accuracy: 0.9625 - 538ms/epoch - 6ms/step
# Epoch 68/200
# 96/96 - 1s - loss: 0.0052 - accuracy: 0.9958 - val_loss: 0.2590 - val_accuracy: 0.9750 - 543ms/epoch - 6ms/step
# Epoch 69/200
# 96/96 - 1s - loss: 0.0350 - accuracy: 0.9927 - val_loss: 0.2312 - val_accuracy: 0.9750 - 556ms/epoch - 6ms/step
# Epoch 70/200
# 96/96 - 1s - loss: 0.0164 - accuracy: 0.9937 - val_loss: 0.3647 - val_accuracy: 0.9708 - 544ms/epoch - 6ms/step
# Epoch 71/200
# 96/96 - 1s - loss: 0.0442 - accuracy: 0.9917 - val_loss: 0.2904 - val_accuracy: 0.9750 - 542ms/epoch - 6ms/step
# Epoch 72/200
# 96/96 - 1s - loss: 0.0228 - accuracy: 0.9937 - val_loss: 0.2786 - val_accuracy: 0.9667 - 553ms/epoch - 6ms/step
# Epoch 73/200
# 96/96 - 1s - loss: 0.0246 - accuracy: 0.9917 - val_loss: 0.2807 - val_accuracy: 0.9750 - 561ms/epoch - 6ms/step
# Epoch 74/200
# 96/96 - 1s - loss: 0.0378 - accuracy: 0.9937 - val_loss: 0.3675 - val_accuracy: 0.9667 - 543ms/epoch - 6ms/step
# Epoch 75/200
# 96/96 - 1s - loss: 0.0289 - accuracy: 0.9937 - val_loss: 0.2250 - val_accuracy: 0.9708 - 552ms/epoch - 6ms/step
# Epoch 76/200
# 96/96 - 1s - loss: 0.0401 - accuracy: 0.9917 - val_loss: 0.3628 - val_accuracy: 0.9708 - 552ms/epoch - 6ms/step
# Epoch 77/200
# 96/96 - 1s - loss: 0.0590 - accuracy: 0.9906 - val_loss: 0.1800 - val_accuracy: 0.9792 - 559ms/epoch - 6ms/step
# Epoch 78/200
# 96/96 - 1s - loss: 0.0148 - accuracy: 0.9948 - val_loss: 0.2345 - val_accuracy: 0.9833 - 558ms/epoch - 6ms/step
# Epoch 79/200
# 96/96 - 1s - loss: 0.0204 - accuracy: 0.9948 - val_loss: 0.2807 - val_accuracy: 0.9708 - 544ms/epoch - 6ms/step
# Epoch 80/200
# 96/96 - 1s - loss: 0.0288 - accuracy: 0.9948 - val_loss: 0.2716 - val_accuracy: 0.9750 - 537ms/epoch - 6ms/step
# Epoch 81/200
# 96/96 - 1s - loss: 0.0073 - accuracy: 0.9969 - val_loss: 0.3399 - val_accuracy: 0.9667 - 555ms/epoch - 6ms/step
# Epoch 82/200
# 96/96 - 1s - loss: 0.0259 - accuracy: 0.9969 - val_loss: 0.3055 - val_accuracy: 0.9667 - 558ms/epoch - 6ms/step
# Epoch 83/200
# 96/96 - 1s - loss: 9.4751e-04 - accuracy: 1.0000 - val_loss: 0.2776 - val_accuracy: 0.9750 - 534ms/epoch - 6ms/step
# Epoch 84/200
# 96/96 - 1s - loss: 0.0282 - accuracy: 0.9937 - val_loss: 0.2540 - val_accuracy: 0.9667 - 568ms/epoch - 6ms/step
# Epoch 85/200
# 96/96 - 1s - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.2646 - val_accuracy: 0.9708 - 540ms/epoch - 6ms/step
# Epoch 86/200
# 96/96 - 1s - loss: 0.0175 - accuracy: 0.9948 - val_loss: 0.4163 - val_accuracy: 0.9708 - 561ms/epoch - 6ms/step
# Epoch 87/200
# 96/96 - 1s - loss: 0.0337 - accuracy: 0.9937 - val_loss: 0.2398 - val_accuracy: 0.9833 - 578ms/epoch - 6ms/step
# Epoch 88/200
# 96/96 - 1s - loss: 0.0155 - accuracy: 0.9958 - val_loss: 0.2774 - val_accuracy: 0.9708 - 550ms/epoch - 6ms/step
# Epoch 89/200
# 96/96 - 1s - loss: 0.0411 - accuracy: 0.9906 - val_loss: 0.2441 - val_accuracy: 0.9875 - 550ms/epoch - 6ms/step
# Epoch 90/200
# 96/96 - 1s - loss: 0.0216 - accuracy: 0.9958 - val_loss: 0.2291 - val_accuracy: 0.9750 - 541ms/epoch - 6ms/step
# Epoch 91/200
# 96/96 - 1s - loss: 0.0128 - accuracy: 0.9969 - val_loss: 0.3164 - val_accuracy: 0.9833 - 554ms/epoch - 6ms/step
# Epoch 92/200
# 96/96 - 1s - loss: 0.0331 - accuracy: 0.9948 - val_loss: 0.3242 - val_accuracy: 0.9750 - 537ms/epoch - 6ms/step
# Epoch 93/200
# 96/96 - 1s - loss: 0.0334 - accuracy: 0.9937 - val_loss: 0.2517 - val_accuracy: 0.9792 - 565ms/epoch - 6ms/step
# Epoch 94/200
# 96/96 - 1s - loss: 0.0302 - accuracy: 0.9958 - val_loss: 0.2456 - val_accuracy: 0.9792 - 540ms/epoch - 6ms/step
# Epoch 95/200
# 96/96 - 1s - loss: 0.0316 - accuracy: 0.9937 - val_loss: 0.2794 - val_accuracy: 0.9792 - 546ms/epoch - 6ms/step
# Epoch 96/200
# 96/96 - 1s - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.2975 - val_accuracy: 0.9792 - 551ms/epoch - 6ms/step
# Epoch 97/200
# 96/96 - 1s - loss: 0.0343 - accuracy: 0.9937 - val_loss: 0.2905 - val_accuracy: 0.9750 - 561ms/epoch - 6ms/step
# Epoch 98/200
# 96/96 - 1s - loss: 0.0162 - accuracy: 0.9969 - val_loss: 0.2490 - val_accuracy: 0.9792 - 537ms/epoch - 6ms/step
# Epoch 99/200
# 96/96 - 1s - loss: 0.0283 - accuracy: 0.9969 - val_loss: 0.2532 - val_accuracy: 0.9750 - 540ms/epoch - 6ms/step
# Epoch 100/200
# 96/96 - 1s - loss: 0.0150 - accuracy: 0.9979 - val_loss: 0.2739 - val_accuracy: 0.9792 - 575ms/epoch - 6ms/step
# Epoch 101/200
# 96/96 - 1s - loss: 0.0047 - accuracy: 0.9979 - val_loss: 0.4531 - val_accuracy: 0.9625 - 546ms/epoch - 6ms/step
# Epoch 102/200
# 96/96 - 1s - loss: 0.0241 - accuracy: 0.9948 - val_loss: 0.3196 - val_accuracy: 0.9750 - 558ms/epoch - 6ms/step
# Epoch 103/200
# 96/96 - 1s - loss: 0.0118 - accuracy: 0.9979 - val_loss: 0.2826 - val_accuracy: 0.9833 - 544ms/epoch - 6ms/step
# Epoch 104/200
# 96/96 - 1s - loss: 0.0125 - accuracy: 0.9948 - val_loss: 0.3103 - val_accuracy: 0.9792 - 554ms/epoch - 6ms/step
# Epoch 105/200
# 96/96 - 1s - loss: 0.0189 - accuracy: 0.9990 - val_loss: 0.2975 - val_accuracy: 0.9750 - 541ms/epoch - 6ms/step
# Epoch 106/200
# 96/96 - 1s - loss: 0.0538 - accuracy: 0.9937 - val_loss: 0.3053 - val_accuracy: 0.9792 - 566ms/epoch - 6ms/step
# Epoch 107/200
# 96/96 - 1s - loss: 0.0012 - accuracy: 0.9990 - val_loss: 0.2806 - val_accuracy: 0.9750 - 543ms/epoch - 6ms/step
# Epoch 108/200
# 96/96 - 1s - loss: 0.0093 - accuracy: 0.9979 - val_loss: 0.2580 - val_accuracy: 0.9750 - 548ms/epoch - 6ms/step
# Epoch 109/200
# 96/96 - 1s - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.3631 - val_accuracy: 0.9667 - 551ms/epoch - 6ms/step
# Epoch 110/200
# 96/96 - 1s - loss: 0.0223 - accuracy: 0.9948 - val_loss: 0.3364 - val_accuracy: 0.9750 - 541ms/epoch - 6ms/step
# Epoch 111/200
# 96/96 - 1s - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.2326 - val_accuracy: 0.9833 - 555ms/epoch - 6ms/step
# Epoch 112/200
# 96/96 - 1s - loss: 0.0095 - accuracy: 0.9958 - val_loss: 0.3784 - val_accuracy: 0.9750 - 549ms/epoch - 6ms/step
# Epoch 113/200
# 96/96 - 1s - loss: 0.0186 - accuracy: 0.9958 - val_loss: 0.3611 - val_accuracy: 0.9750 - 551ms/epoch - 6ms/step
# Epoch 114/200
# 96/96 - 1s - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.4406 - val_accuracy: 0.9750 - 555ms/epoch - 6ms/step
# Epoch 115/200
# 96/96 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3781 - val_accuracy: 0.9708 - 560ms/epoch - 6ms/step
# Epoch 116/200
# 96/96 - 1s - loss: 0.0393 - accuracy: 0.9927 - val_loss: 0.3005 - val_accuracy: 0.9833 - 548ms/epoch - 6ms/step
# Epoch 117/200
# 96/96 - 1s - loss: 1.7451e-04 - accuracy: 1.0000 - val_loss: 0.3569 - val_accuracy: 0.9750 - 559ms/epoch - 6ms/step
# Epoch 118/200
# 96/96 - 1s - loss: 0.0555 - accuracy: 0.9927 - val_loss: 0.3342 - val_accuracy: 0.9792 - 558ms/epoch - 6ms/step
# Epoch 119/200
# 96/96 - 1s - loss: 0.0318 - accuracy: 0.9937 - val_loss: 0.4375 - val_accuracy: 0.9750 - 564ms/epoch - 6ms/step
# Epoch 120/200
# 96/96 - 1s - loss: 0.0319 - accuracy: 0.9937 - val_loss: 0.4064 - val_accuracy: 0.9667 - 550ms/epoch - 6ms/step
# Epoch 121/200
# 96/96 - 1s - loss: 0.0111 - accuracy: 0.9969 - val_loss: 0.2978 - val_accuracy: 0.9750 - 550ms/epoch - 6ms/step
# Epoch 122/200
# 96/96 - 1s - loss: 0.0113 - accuracy: 0.9979 - val_loss: 0.3339 - val_accuracy: 0.9750 - 566ms/epoch - 6ms/step
# Epoch 123/200
# 96/96 - 1s - loss: 0.0249 - accuracy: 0.9958 - val_loss: 0.3023 - val_accuracy: 0.9750 - 560ms/epoch - 6ms/step
# Epoch 124/200
# 96/96 - 1s - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.2894 - val_accuracy: 0.9750 - 597ms/epoch - 6ms/step
# Epoch 125/200
# 96/96 - 1s - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.3962 - val_accuracy: 0.9792 - 549ms/epoch - 6ms/step
# Epoch 126/200
# 96/96 - 1s - loss: 8.7619e-04 - accuracy: 1.0000 - val_loss: 0.2933 - val_accuracy: 0.9792 - 790ms/epoch - 8ms/step
# Epoch 127/200
# 96/96 - 1s - loss: 0.0377 - accuracy: 0.9948 - val_loss: 0.3377 - val_accuracy: 0.9750 - 796ms/epoch - 8ms/step
# Epoch 128/200
# 96/96 - 1s - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.3495 - val_accuracy: 0.9667 - 986ms/epoch - 10ms/step
# Epoch 129/200
# 96/96 - 1s - loss: 0.0128 - accuracy: 0.9969 - val_loss: 0.3522 - val_accuracy: 0.9750 - 535ms/epoch - 6ms/step
# Epoch 130/200
# 96/96 - 1s - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.3241 - val_accuracy: 0.9792 - 553ms/epoch - 6ms/step
# Epoch 131/200
# 96/96 - 1s - loss: 1.7996e-04 - accuracy: 1.0000 - val_loss: 0.3970 - val_accuracy: 0.9792 - 553ms/epoch - 6ms/step
# Epoch 132/200
# 96/96 - 1s - loss: 3.8053e-04 - accuracy: 1.0000 - val_loss: 0.3739 - val_accuracy: 0.9750 - 540ms/epoch - 6ms/step
# Epoch 133/200
# 96/96 - 1s - loss: 0.0134 - accuracy: 0.9979 - val_loss: 0.4534 - val_accuracy: 0.9625 - 553ms/epoch - 6ms/step
# Epoch 134/200
# 96/96 - 1s - loss: 0.0247 - accuracy: 0.9958 - val_loss: 0.3020 - val_accuracy: 0.9833 - 554ms/epoch - 6ms/step
# Epoch 135/200
# 96/96 - 1s - loss: 0.0380 - accuracy: 0.9927 - val_loss: 0.5554 - val_accuracy: 0.9667 - 557ms/epoch - 6ms/step
# Epoch 136/200
# 96/96 - 1s - loss: 0.0508 - accuracy: 0.9937 - val_loss: 0.4021 - val_accuracy: 0.9708 - 546ms/epoch - 6ms/step
# Epoch 137/200
# 96/96 - 1s - loss: 6.9355e-05 - accuracy: 1.0000 - val_loss: 0.3266 - val_accuracy: 0.9708 - 556ms/epoch - 6ms/step
# Epoch 138/200
# 96/96 - 1s - loss: 0.0183 - accuracy: 0.9990 - val_loss: 0.3745 - val_accuracy: 0.9750 - 550ms/epoch - 6ms/step
# Epoch 139/200
# 96/96 - 1s - loss: 0.0210 - accuracy: 0.9969 - val_loss: 0.4286 - val_accuracy: 0.9667 - 547ms/epoch - 6ms/step
# Epoch 140/200
# 96/96 - 1s - loss: 0.0138 - accuracy: 0.9969 - val_loss: 0.3397 - val_accuracy: 0.9708 - 579ms/epoch - 6ms/step
# Epoch 141/200
# 96/96 - 1s - loss: 2.0680e-04 - accuracy: 1.0000 - val_loss: 0.4247 - val_accuracy: 0.9750 - 553ms/epoch - 6ms/step
# Epoch 142/200
# 96/96 - 1s - loss: 0.0182 - accuracy: 0.9958 - val_loss: 0.3738 - val_accuracy: 0.9750 - 562ms/epoch - 6ms/step
# Epoch 143/200
# 96/96 - 1s - loss: 0.0153 - accuracy: 0.9958 - val_loss: 0.3379 - val_accuracy: 0.9750 - 534ms/epoch - 6ms/step
# Epoch 144/200
# 96/96 - 1s - loss: 0.0255 - accuracy: 0.9969 - val_loss: 0.7369 - val_accuracy: 0.9667 - 543ms/epoch - 6ms/step
# Epoch 145/200
# 96/96 - 1s - loss: 0.0132 - accuracy: 0.9979 - val_loss: 0.3150 - val_accuracy: 0.9792 - 555ms/epoch - 6ms/step
# Epoch 146/200
# 96/96 - 1s - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.3940 - val_accuracy: 0.9625 - 563ms/epoch - 6ms/step
# Epoch 147/200
# 96/96 - 1s - loss: 0.0221 - accuracy: 0.9969 - val_loss: 0.4359 - val_accuracy: 0.9792 - 548ms/epoch - 6ms/step
# Epoch 148/200
# 96/96 - 1s - loss: 0.0270 - accuracy: 0.9948 - val_loss: 0.4351 - val_accuracy: 0.9708 - 590ms/epoch - 6ms/step
# Epoch 149/200
# 96/96 - 1s - loss: 0.0518 - accuracy: 0.9927 - val_loss: 0.4146 - val_accuracy: 0.9833 - 559ms/epoch - 6ms/step
# Epoch 150/200
# 96/96 - 1s - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.3660 - val_accuracy: 0.9708 - 560ms/epoch - 6ms/step
# Epoch 151/200
# 96/96 - 1s - loss: 0.0531 - accuracy: 0.9948 - val_loss: 0.3177 - val_accuracy: 0.9708 - 559ms/epoch - 6ms/step
# Epoch 152/200
# 96/96 - 1s - loss: 0.0128 - accuracy: 0.9969 - val_loss: 0.3273 - val_accuracy: 0.9750 - 561ms/epoch - 6ms/step
# Epoch 153/200
# 96/96 - 1s - loss: 0.0012 - accuracy: 0.9990 - val_loss: 0.3501 - val_accuracy: 0.9750 - 549ms/epoch - 6ms/step
# Epoch 154/200
# 96/96 - 1s - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.3380 - val_accuracy: 0.9792 - 552ms/epoch - 6ms/step
# Epoch 155/200
# 96/96 - 1s - loss: 0.0158 - accuracy: 0.9969 - val_loss: 0.3210 - val_accuracy: 0.9833 - 555ms/epoch - 6ms/step
# Epoch 156/200
# 96/96 - 1s - loss: 0.0326 - accuracy: 0.9958 - val_loss: 0.2900 - val_accuracy: 0.9750 - 535ms/epoch - 6ms/step
# Epoch 157/200
# 96/96 - 1s - loss: 0.0130 - accuracy: 0.9948 - val_loss: 0.4758 - val_accuracy: 0.9708 - 564ms/epoch - 6ms/step
# Epoch 158/200
# 96/96 - 1s - loss: 0.0244 - accuracy: 0.9948 - val_loss: 0.3333 - val_accuracy: 0.9833 - 554ms/epoch - 6ms/step
# Epoch 159/200
# 96/96 - 1s - loss: 0.0080 - accuracy: 0.9990 - val_loss: 0.3430 - val_accuracy: 0.9792 - 565ms/epoch - 6ms/step
# Epoch 160/200
# 96/96 - 1s - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.3483 - val_accuracy: 0.9833 - 547ms/epoch - 6ms/step
# Epoch 161/200
# 96/96 - 1s - loss: 5.6982e-05 - accuracy: 1.0000 - val_loss: 0.4028 - val_accuracy: 0.9708 - 549ms/epoch - 6ms/step
# Epoch 162/200
# 96/96 - 1s - loss: 0.0313 - accuracy: 0.9969 - val_loss: 0.4898 - val_accuracy: 0.9750 - 555ms/epoch - 6ms/step
# Epoch 163/200
# 96/96 - 1s - loss: 0.0329 - accuracy: 0.9979 - val_loss: 0.3901 - val_accuracy: 0.9792 - 554ms/epoch - 6ms/step
# Epoch 164/200
# 96/96 - 1s - loss: 0.0220 - accuracy: 0.9969 - val_loss: 0.4412 - val_accuracy: 0.9792 - 545ms/epoch - 6ms/step
# Epoch 165/200
# 96/96 - 1s - loss: 0.0404 - accuracy: 0.9969 - val_loss: 0.4358 - val_accuracy: 0.9833 - 547ms/epoch - 6ms/step
# Epoch 166/200
# 96/96 - 1s - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.3497 - val_accuracy: 0.9833 - 548ms/epoch - 6ms/step
# Epoch 167/200
# 96/96 - 1s - loss: 5.2416e-05 - accuracy: 1.0000 - val_loss: 0.4087 - val_accuracy: 0.9833 - 546ms/epoch - 6ms/step
# Epoch 168/200
# 96/96 - 1s - loss: 0.0273 - accuracy: 0.9958 - val_loss: 0.3578 - val_accuracy: 0.9792 - 551ms/epoch - 6ms/step
# Epoch 169/200
# 96/96 - 1s - loss: 0.0069 - accuracy: 0.9969 - val_loss: 0.3555 - val_accuracy: 0.9792 - 552ms/epoch - 6ms/step
# Epoch 170/200
# 96/96 - 1s - loss: 0.0097 - accuracy: 0.9979 - val_loss: 0.2689 - val_accuracy: 0.9917 - 565ms/epoch - 6ms/step
# Epoch 171/200
# 96/96 - 1s - loss: 0.0078 - accuracy: 0.9979 - val_loss: 0.3237 - val_accuracy: 0.9833 - 556ms/epoch - 6ms/step
# Epoch 172/200
# 96/96 - 1s - loss: 0.0079 - accuracy: 0.9969 - val_loss: 0.3932 - val_accuracy: 0.9792 - 546ms/epoch - 6ms/step
# Epoch 173/200
# 96/96 - 1s - loss: 0.0062 - accuracy: 0.9969 - val_loss: 0.3457 - val_accuracy: 0.9833 - 556ms/epoch - 6ms/step
# Epoch 174/200
# 96/96 - 1s - loss: 0.0137 - accuracy: 0.9969 - val_loss: 0.6193 - val_accuracy: 0.9583 - 552ms/epoch - 6ms/step
# Epoch 175/200
# 96/96 - 1s - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.3348 - val_accuracy: 0.9833 - 552ms/epoch - 6ms/step
# Epoch 176/200
# 96/96 - 1s - loss: 2.3732e-05 - accuracy: 1.0000 - val_loss: 0.3431 - val_accuracy: 0.9875 - 545ms/epoch - 6ms/step
# Epoch 177/200
# 96/96 - 1s - loss: 0.0020 - accuracy: 0.9990 - val_loss: 0.5928 - val_accuracy: 0.9708 - 568ms/epoch - 6ms/step
# Epoch 178/200
# 96/96 - 1s - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.3642 - val_accuracy: 0.9792 - 543ms/epoch - 6ms/step
# Epoch 179/200
# 96/96 - 1s - loss: 0.0292 - accuracy: 0.9948 - val_loss: 0.4278 - val_accuracy: 0.9750 - 561ms/epoch - 6ms/step
# Epoch 180/200
# 96/96 - 1s - loss: 0.0138 - accuracy: 0.9969 - val_loss: 0.3434 - val_accuracy: 0.9875 - 555ms/epoch - 6ms/step
# Epoch 181/200
# 96/96 - 1s - loss: 0.0384 - accuracy: 0.9958 - val_loss: 0.4110 - val_accuracy: 0.9792 - 587ms/epoch - 6ms/step
# Epoch 182/200
# 96/96 - 1s - loss: 0.0233 - accuracy: 0.9969 - val_loss: 0.4833 - val_accuracy: 0.9792 - 547ms/epoch - 6ms/step
# Epoch 183/200
# 96/96 - 1s - loss: 4.6752e-05 - accuracy: 1.0000 - val_loss: 0.4212 - val_accuracy: 0.9833 - 557ms/epoch - 6ms/step
# Epoch 184/200
# 96/96 - 1s - loss: 0.0149 - accuracy: 0.9979 - val_loss: 0.3947 - val_accuracy: 0.9750 - 553ms/epoch - 6ms/step
# Epoch 185/200
# 96/96 - 1s - loss: 0.0060 - accuracy: 0.9969 - val_loss: 0.4452 - val_accuracy: 0.9833 - 553ms/epoch - 6ms/step
# Epoch 186/200
# 96/96 - 1s - loss: 0.0237 - accuracy: 0.9958 - val_loss: 0.4131 - val_accuracy: 0.9708 - 548ms/epoch - 6ms/step
# Epoch 187/200
# 96/96 - 1s - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.5328 - val_accuracy: 0.9667 - 550ms/epoch - 6ms/step
# Epoch 188/200
# 96/96 - 1s - loss: 1.6669e-04 - accuracy: 1.0000 - val_loss: 0.3821 - val_accuracy: 0.9750 - 570ms/epoch - 6ms/step
# Epoch 189/200
# 96/96 - 1s - loss: 0.0212 - accuracy: 0.9958 - val_loss: 0.3965 - val_accuracy: 0.9792 - 557ms/epoch - 6ms/step
# Epoch 190/200
# 96/96 - 1s - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.3550 - val_accuracy: 0.9792 - 568ms/epoch - 6ms/step
# Epoch 191/200
# 96/96 - 1s - loss: 2.6853e-05 - accuracy: 1.0000 - val_loss: 0.4204 - val_accuracy: 0.9750 - 556ms/epoch - 6ms/step
# Epoch 192/200
# 96/96 - 1s - loss: 2.3595e-05 - accuracy: 1.0000 - val_loss: 0.5367 - val_accuracy: 0.9792 - 557ms/epoch - 6ms/step
# Epoch 193/200
# 96/96 - 1s - loss: 0.0284 - accuracy: 0.9958 - val_loss: 0.3803 - val_accuracy: 0.9792 - 562ms/epoch - 6ms/step
# Epoch 194/200
# 96/96 - 1s - loss: 0.0179 - accuracy: 0.9979 - val_loss: 0.4393 - val_accuracy: 0.9792 - 548ms/epoch - 6ms/step
# Epoch 195/200
# 96/96 - 1s - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.3881 - val_accuracy: 0.9792 - 574ms/epoch - 6ms/step
# Epoch 196/200
# 96/96 - 1s - loss: 0.0143 - accuracy: 0.9979 - val_loss: 0.4515 - val_accuracy: 0.9792 - 545ms/epoch - 6ms/step
# Epoch 197/200
# 96/96 - 1s - loss: 0.0132 - accuracy: 0.9979 - val_loss: 0.4802 - val_accuracy: 0.9750 - 556ms/epoch - 6ms/step
# Epoch 198/200
# 96/96 - 1s - loss: 0.0132 - accuracy: 0.9979 - val_loss: 0.5063 - val_accuracy: 0.9750 - 553ms/epoch - 6ms/step
# Epoch 199/200
# 96/96 - 1s - loss: 0.0409 - accuracy: 0.9979 - val_loss: 0.3828 - val_accuracy: 0.9750 - 552ms/epoch - 6ms/step
# Epoch 200/200
# 96/96 - 1s - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.4530 - val_accuracy: 0.9792 - 549ms/epoch - 6ms/step

# %% [markdown]
# ### Hopefully your CNN worked *very* well! We want to keep the doggos as safe as they can be.
#
# ![](https://images.pexels.com/photos/316/black-and-white-animal-dog-pet.jpg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940)

# %% [markdown]
# # Challenge Exercise: Explainability through Saliency Maps

# %% [markdown]
# Neural networks have achieved incredible results in many fields. But they have a big problem: it’s very difficult to explain exactly why a neural network makes the decisions it does. This makes it difficult to trust them in high-stakes applications like medicine, self-driving cars, and criminal justice - would you trust an AI that diagnosed you with a disease, but couldn’t explain why?
#
# Other classifiers are much more explainable:
#
# *   With logistic regression, we can see the coefficient (importance) attached to each input feature.
# *   With a decision tree, we can trace a particular decision down the tree.
# *   With KNN, we can examine the nearby neighbors.
#
# Our CNN, above, works well. For example, let's try choosing an image from our dataset and classifying it.

# %%
image_index = 70 #pick any image you'd like
input_image = X_test[image_index] 
print (input_image.shape) 
print (input_image) #How many numbers are there? What does each represent?

plt.imshow(input_image.reshape(32,32,3).astype(int))
plt.show()

print ('Classification:')
print(cnn.predict(np.array([input_image]))) #Our predict function expects a 2D array.
#0 means dog, 1 means road
# Out:
# (3072,)
# [144. 144. 148. ... 207. 173. 142.]
# Classification:
# [0]

# %% [markdown]
# But why did the CNN reach that decision? It’s really hard to give a clear answer! The CNN relies on multiplying input features by the weights it has set. You can print out and look at the hundreds of weights:

# %%
#Warning: expect a large output!
for layer_weights in history.model.weights:
  print (layer_weights)
# Out:
# <tf.Variable 'conv2d_49/kernel:0' shape=(3, 3, 3, 32) dtype=float32, numpy=
# array([[[[-5.26094995e-03, -7.12810755e-02,  1.22704520e-03,
#            1.22931354e-01, -1.34395093e-01,  1.08209495e-02,
#           -1.33671567e-01,  2.37213681e-03,  7.25377724e-02,
#            3.36973816e-02, -1.27437443e-01, -2.06971839e-02,
#           -7.83798620e-02,  4.26035300e-02,  1.24997064e-01,
#           -1.36513472e-01,  8.10755938e-02,  4.85184416e-02,
#            1.12538755e-01,  4.26822156e-02, -9.76621956e-02,
#            4.84915625e-04,  8.30862746e-02,  1.08963609e-01,
#           -3.93364346e-03,  4.68585221e-03, -4.50729392e-02,
#           -6.79568350e-02,  3.35659757e-02, -5.76521009e-02,
#            4.43517938e-02,  6.44042250e-03],
#          [-2.19330620e-02, -9.35052112e-02, -4.36808579e-02,
#           -8.03813487e-02,  1.17599368e-01,  7.77855515e-02,
#           -1.79393515e-02,  1.20879337e-01,  6.46052824e-04,
#           -4.93133552e-02,  1.07230684e-02, -1.09633788e-01,
#            6.18283153e-02,  9.09160636e-03, -8.12832043e-02,
#           -8.53827521e-02, -1.02671333e-01, -7.61334673e-02,
#           -3.96512710e-02,  8.28631148e-02,  7.19856471e-02,
#            5.32878414e-02,  8.03616270e-02, -5.15517071e-02,
#           -1.50770219e-02, -1.90930348e-02, -6.57572523e-02,
#            8.84423312e-03, -5.87943755e-02,  1.20193489e-01,
#           -1.08671680e-01,  1.32958174e-01],
#          [-4.51829061e-02, -1.08114623e-01, -1.41167834e-01,
#           -1.18783906e-01, -1.09011948e-01,  5.31484187e-02,
#            8.73380080e-02, -8.14016238e-02, -7.09175318e-02,
#            6.98465155e-03,  7.86678866e-02,  9.89231840e-03,
#           -1.17339253e-01,  9.65579003e-02,  7.75016174e-02,
#            8.23708326e-02, -7.81939179e-02, -1.08903356e-01,
#            1.84737109e-02,  4.26423810e-02, -2.03200355e-02,
#            8.73904377e-02,  5.83940744e-02,  4.13937075e-03,
#            1.06862793e-02,  4.82671261e-02, -7.08178356e-02,
#           -2.64062267e-02, -1.34656429e-01, -2.34013889e-02,
#         [[-0.06254873, -0.04139036,  0.09663129, ...,  0.02924208,
#            0.01799252,  0.06713293],
#          [ 0.036506  , -0.01552987, -0.06956274, ..., -0.00195613,
#            0.00507888,  0.07325217],
#          [ 0.00153178, -0.04020085, -0.03532716, ...,  0.0080688 ,
#            0.07805321, -0.06615851],
#          ...,
#          [-0.09371411,  0.0596041 , -0.01403322, ..., -0.10380414,
#           -0.01803993,  0.02538333],
#          [-0.08105329,  0.0114914 , -0.10018141, ...,  0.02374754,
#            0.07973566, -0.02862608],
#          [-0.05862861, -0.09033932, -0.02948091, ...,  0.00521457,
#           -0.02956617, -0.1065759 ]],
#
#         [[-0.09011043,  0.06174787,  0.04452714, ...,  0.00748293,
#           -0.02543285, -0.07345312],
#          [ 0.01362947,  0.05470758, -0.04160874, ..., -0.09934966,
#            0.07982754,  0.07144333],
#          [-0.04979198, -0.06732184,  0.08725341, ..., -0.07081559,
#            0.07037094,  0.05341981],
#          ...,
#          [-0.06844314, -0.08096122,  0.08957902, ..., -0.01084015,
#           -0.0206729 ,  0.07701176],
#          [ 0.06841692, -0.05741188,  0.00149167, ...,  0.02713986,
#            0.08039146,  0.01501209],
#          [-0.04588109,  0.09484556,  0.09870743, ...,  0.02434334,
#            0.04826338, -0.0576301 ]]],
#
#
#        [[[ 0.06958622,  0.05217398, -0.02209246, ...,  0.02762074,
#           -0.04193558,  0.07766797],
#          [-0.01447698, -0.04306643,  0.0158851 , ...,  0.02850434,
#           -0.056129  ,  0.09621881],
#          [ 0.05041615,  0.06387428, -0.00957548, ...,  0.076974  ,
#            0.05438872, -0.0253821 ],
#          ...,
#          [-0.02293595,  0.12084564,  0.0726394 , ...,  0.0656941 ,
#           -0.03957837, -0.00891707],
#          [-0.0302344 ,  0.01877543,  0.07398427, ..., -0.0682356 ,
#           -0.09908749, -0.03231959],
#          [ 0.01342825, -0.04535868,  0.04997979, ...,  0.02832675,
#           -0.07212821,  0.04584626]],
#
#         [[ 0.07191135,  0.05017179,  0.0916316 , ...,  0.05647971,
#            0.02798954,  0.05171875],
#          [-0.07559374,  0.06495639,  0.09672625, ..., -0.05871443,
#            0.08709648,  0.0390101 ],
#          [-0.11802211,  0.07478127, -0.06650274, ...,  0.0231229 ,
#            0.05699809, -0.08078963],
#          ...,
#          [ 0.04460724,  0.06633344, -0.03525775, ...,  0.03632775,
#            0.0986449 ,  0.00149657],
#          [-0.00196175,  0.09263634,  0.04897317, ...,  0.04569754,
#            0.10787261, -0.03964736],
#          [-0.03295907,  0.04024343, -0.10003392, ...,  0.08669043,
#            0.08212259,  0.01043538]],
#
#         [[ 0.07542942,  0.03025212,  0.00119413, ..., -0.03442473,
#            0.03343612, -0.03830004],
#          [ 0.08296977,  0.05077469, -0.02539192, ...,  0.10326508,
#            0.0799219 , -0.07473745],
#          [-0.04793186, -0.05576831,  0.08995342, ...,  0.06690037,
#           -0.0928793 , -0.03892283],
#          ...,
#          [-0.04308404,  0.05672295, -0.01903533, ..., -0.01496042,
#            0.04651662,  0.08925454],
#          [-0.00477304, -0.02372525, -0.03626068, ..., -0.03854731,
#           -0.00817427,  0.10542417],
#          [ 0.04257889, -0.00094441, -0.06579857, ..., -0.09448474,
#           -0.02516685, -0.001979  ]]],
#
#
#        [[[ 0.02349532,  0.05146013,  0.09426276, ..., -0.10090975,
#            0.05430011, -0.06509594],
#          [ 0.05712419, -0.06023106, -0.03194517, ...,  0.09557169,
#            0.0438559 , -0.04084019],
#          [ 0.08989275,  0.07030076, -0.08389599, ...,  0.05037091,
#            0.07077904,  0.08323438],
#          ...,
#          [-0.05801873,  0.08711529,  0.10023693, ...,  0.08899863,
#            0.05887914, -0.02220146],
#          [-0.07555231,  0.00638345,  0.02970013, ...,  0.03906561,
#            0.00496318,  0.10115875],
#          [ 0.09565905,  0.05637308, -0.02953834, ...,  0.06496376,
#           -0.0066159 , -0.07795874]],
#
#         [[ 0.07104815,  0.06390222,  0.05659799, ...,  0.06164427,
#           -0.00799242, -0.04134091],
#          [-0.09380371,  0.07805702, -0.06876016, ...,  0.02307423,
#           -0.08843634, -0.08029891],
#          [-0.08439497, -0.05527757,  0.08771251, ..., -0.04620788,
#           -0.02973337, -0.09764051],
#          ...,
#          [ 0.02336663, -0.01678292, -0.06287892, ...,  0.04003137,
#            0.03422931,  0.01269697],
#          [ 0.01574037, -0.0185722 ,  0.00752803, ...,  0.02787502,
#           -0.07609687, -0.08334266],
#          [-0.02404635,  0.04675744,  0.04577527, ...,  0.03940758,
#            0.0201297 , -0.03855145]],
#
#         [[-0.00061886, -0.01672561, -0.08613092, ...,  0.02398752,
#           -0.07865866, -0.074824  ],
#          [-0.05278089, -0.07117803,  0.09450376, ...,  0.06902388,
#           -0.05017613,  0.09248223],
#          [ 0.004136  , -0.05894439,  0.01988875, ...,  0.07327553,
#            0.05061127, -0.00507184],
#          ...,
#          [ 0.11160713, -0.01557273, -0.03126127, ...,  0.06902631,
#           -0.0327923 ,  0.02868429],
#          [ 0.06229157, -0.0770973 ,  0.03427011, ..., -0.06620165,
#            0.09550529,  0.10347133],
#          [ 0.05685886, -0.0931601 , -0.02024784, ...,  0.0134939 ,
#           -0.09412909, -0.00592182]]]], dtype=float32)>
# <tf.Variable 'conv2d_50/bias:0' shape=(32,) dtype=float32, numpy=
# array([ 0.0013282 , -0.00087819,  0.01090784,  0.0071817 , -0.00092815,
#         0.01304435, -0.00207006,  0.00191269,  0.01785702, -0.00443285,
#        -0.00291456,  0.00633785,  0.00308023,  0.00279677, -0.02259773,
#         0.00225188,  0.00663159,  0.02026386, -0.00297939,  0.00502095,
#         0.00517402, -0.01032242,  0.00978568, -0.00563924, -0.00606732,
#         0.01815614, -0.00544748, -0.00949936,  0.00750892, -0.00604685,
#         0.00874892, -0.00783582], dtype=float32)>
# <tf.Variable 'conv2d_51/kernel:0' shape=(3, 3, 32, 32) dtype=float32, numpy=
# array([[[[-0.00864418, -0.06740187, -0.03124329, ...,  0.03076712,
#            0.06289067,  0.05074594],
#          [-0.07896031,  0.02255843, -0.02413397, ...,  0.01362507,
#            0.05909986,  0.07366747],
#          [-0.01910173, -0.06777272, -0.07396361, ...,  0.00666525,
#           -0.02279648, -0.08447565],
#          ...,
#          [ 0.09280267, -0.04065832, -0.09128941, ...,  0.00585494,
#           -0.0290028 , -0.02003318],
#          [ 0.01163849,  0.08189525,  0.09053225, ..., -0.07265331,
#            0.09352775,  0.05862381],
#          [-0.06527486,  0.04228182, -0.08890072, ...,  0.02215354,
#            0.04977581, -0.04729993]],
#
#         [[-0.02643638,  0.02765786, -0.02240433, ...,  0.05542101,
#           -0.08461616, -0.07374572],
#          [ 0.07520871,  0.03145955, -0.04649802, ..., -0.07176846,
#            0.0135045 ,  0.00627835],
#          [-0.02635022, -0.06061334,  0.03833199, ..., -0.05807218,
#            0.01688011, -0.07639991],
#          ...,
#          [-0.09908582, -0.09425672, -0.06230103, ...,  0.00318758,
#           -0.02486225, -0.02749059],
#          [-0.10680211, -0.02684572,  0.01005016, ..., -0.0615864 ,
#            0.11555759,  0.01018355],
#          [ 0.08702578,  0.05147317, -0.01048209, ...,  0.09262602,
#            0.06611751, -0.01988343]],
#
#         [[-0.0978448 ,  0.00043295,  0.0404262 , ..., -0.02975166,
#            0.09960519, -0.00974275],
#          [-0.0638148 , -0.05093819, -0.03753021, ..., -0.04711142,
#           -0.06259514, -0.03314197],
#          [-0.01950919,  0.03938154,  0.05927007, ..., -0.06202918,
#           -0.03734441, -0.07255638],
#          ...,
#          [ 0.04610679,  0.08886727,  0.02547311, ..., -0.07764485,
#            0.01952194, -0.084533  ],
#          [ 0.01339604,  0.00169606,  0.03319497, ...,  0.05547298,
#            0.11494026,  0.09266477],
#          [-0.0360623 ,  0.0046497 , -0.04099092, ..., -0.0234743 ,
#           -0.07139633,  0.01227133]]],
#
#
#        [[[-0.08244081, -0.00496055,  0.0312888 , ..., -0.07593576,
#            0.06513212,  0.07262664],
#          [-0.03365494, -0.00846066,  0.06892814, ...,  0.06021298,
#           -0.06419276, -0.00704319],
#          [-0.03944062, -0.03043086, -0.07939222, ...,  0.02076827,
#            0.01750746,  0.00373365],
#          ...,
#          [ 0.08666318, -0.01807781,  0.07767578, ..., -0.0828924 ,
#           -0.06849435,  0.0303015 ],
#          [-0.0352031 ,  0.11416807, -0.00254107, ...,  0.02158842,
#           -0.10776821, -0.10894947],
#          [-0.06791399, -0.06123824, -0.07480083, ..., -0.08049422,
#           -0.07837093, -0.08478159]],
#
#         [[ 0.03429969,  0.05703913,  0.07393327, ...,  0.07128914,
#           -0.00272573,  0.05854862],
#          [-0.06548966,  0.10067923,  0.01717731, ...,  0.04797767,
#           -0.01698721, -0.03184075],
#          [ 0.08482881,  0.0551067 , -0.00655326, ..., -0.06763694,
#            0.0127979 , -0.02377439],
#          ...,
#          [-0.02093082,  0.07491519, -0.07331939, ..., -0.03994835,
#            0.04937501, -0.00887213],
#          [ 0.07926013,  0.09520487, -0.10797585, ...,  0.039218  ,
#           -0.07632211, -0.06271369],
#          [ 0.07511922, -0.0996833 ,  0.03920809, ...,  0.09471431,
#           -0.01571575,  0.08493833]],
#
#         [[-0.08246912, -0.06846273,  0.1003904 , ...,  0.02976093,
#           -0.06718041,  0.00108593],
#          [ 0.01892351, -0.03477287,  0.09268827, ...,  0.01038493,
#           -0.00846702, -0.07849723],
#          [-0.04632695, -0.09017152, -0.04595844, ...,  0.05492158,
#           -0.04892817,  0.11879338],
#          ...,
#          [-0.07628204, -0.09512292,  0.09389542, ..., -0.05652973,
#            0.02081879, -0.07185046],
#          [-0.02912029, -0.05058919, -0.1001948 , ..., -0.04564388,
#           -0.06167154,  0.02009491],
#          [-0.09189668, -0.0238684 ,  0.06285515, ..., -0.02821136,
#           -0.01605642,  0.0859082 ]]],
#
#
#        [[[-0.03388931,  0.05797506, -0.040852  , ..., -0.07970597,
#            0.00169486, -0.07312511],
#          [-0.1016921 , -0.0873038 ,  0.01357637, ...,  0.01648625,
#           -0.02767693, -0.01465946],
#          [ 0.06593458,  0.06611467,  0.03993364, ..., -0.07869949,
#           -0.07175063,  0.02236118],
#          ...,
#          [-0.04816839,  0.01054683,  0.03616132, ..., -0.08733913,
#           -0.02736512, -0.01302365],
#          [-0.0488602 ,  0.06453215, -0.02939802, ...,  0.05058448,
#           -0.0176613 ,  0.06120241],
#          [-0.05652698,  0.0748577 , -0.02393343, ...,  0.09795573,
#            0.07706703,  0.00277177]],
#
#         [[ 0.01395655,  0.06851852, -0.05144811, ..., -0.03720406,
#            0.01045473, -0.08048612],
#          [ 0.04048739,  0.06877087,  0.0153594 , ...,  0.03847738,
#            0.08545756, -0.022647  ],
#          [ 0.00543381, -0.07396632,  0.09656721, ..., -0.02983035,
#           -0.03040641, -0.08733208],
#          ...,
#          [ 0.00304345,  0.05098728,  0.07259791, ..., -0.07635465,
#            0.06818209,  0.08935286],
#          [-0.0795261 ,  0.06054312, -0.11772437, ...,  0.09681663,
#            0.09369975, -0.04664926],
#          [-0.02970075, -0.02786105, -0.08270389, ...,  0.08202298,
#           -0.07691491,  0.01774668]],
#
#         [[-0.01413072, -0.06059676, -0.00665909, ...,  0.07269695,
#            0.078937  , -0.04709059],
#          [-0.07227866, -0.0719787 ,  0.05898425, ..., -0.02557614,
#           -0.03386274, -0.0336149 ],
#          [-0.04017353,  0.05855635, -0.04249678, ...,  0.0381842 ,
#           -0.09392267, -0.04065723],
#          ...,
#          [ 0.02614244, -0.01997958, -0.03686175, ...,  0.01292484,
#           -0.06321593, -0.03529417],
#          [ 0.09458287,  0.09862489,  0.07303704, ..., -0.1117589 ,
#            0.00044484,  0.0150697 ],
#          [ 0.04902739,  0.01668422, -0.09349601, ...,  0.06777839,
#           -0.02698921,  0.01590149]]]], dtype=float32)>
# <tf.Variable 'conv2d_51/bias:0' shape=(32,) dtype=float32, numpy=
# array([ 1.44495592e-02,  5.43776248e-03,  5.15717128e-03, -7.89496058e-04,
#         1.36357741e-02, -1.19039528e-02, -1.02771155e-03, -5.43871829e-05,
#         1.60285346e-02,  4.60511632e-03, -8.84069502e-03, -1.83672970e-03,
#         3.40935681e-03, -3.17630754e-03, -3.07110779e-04, -5.63489506e-03,
#        -7.81871565e-03, -1.72293801e-02,  2.26298198e-02,  1.02120815e-02,
#        -5.86000970e-03,  2.12016050e-03, -5.16118761e-03,  8.53246823e-03,
#         1.66608784e-02,  1.07303327e-02, -3.19772563e-03, -1.12144491e-02,
#         1.38273730e-03,  1.18600123e-03, -1.11660417e-02, -5.35921101e-03],
#       dtype=float32)>
# <tf.Variable 'conv2d_52/kernel:0' shape=(3, 3, 32, 32) dtype=float32, numpy=
# array([[[[ 0.00642897, -0.06671107,  0.03209963, ..., -0.00116637,
#            0.08888934,  0.00944319],
#          [-0.01773083, -0.02992963, -0.04305318, ..., -0.10043576,
#           -0.0173155 , -0.05803188],
#          [-0.05197882,  0.02062117, -0.06861045, ...,  0.04109825,
#            0.07996404,  0.10177439],
#          ...,
#          [ 0.02770313, -0.04476127,  0.0917973 , ..., -0.00201662,
#           -0.03795272,  0.04835844],
#          [ 0.01012552, -0.09676141,  0.03991525, ...,  0.00739922,
#           -0.00388495,  0.0721695 ],
#          [ 0.01884987,  0.03542709,  0.09901214, ...,  0.10270613,
#           -0.0677036 ,  0.06054658]],
#
#         [[ 0.05542308, -0.0604293 , -0.04716009, ...,  0.05493266,
#            0.04939082,  0.04301394],
#          [-0.10226573, -0.07456098, -0.09796806, ..., -0.00560763,
#           -0.0767824 ,  0.05360588],
#          [-0.05935935,  0.07030352,  0.02309177, ...,  0.03029638,
#           -0.04162077,  0.00311186],
#          ...,
#          [-0.02867478,  0.01364474, -0.0800681 , ...,  0.06359345,
#           -0.00489137, -0.04953406],
#          [-0.07836035,  0.01199047, -0.02190123, ..., -0.03512391,
#           -0.01623445,  0.0956314 ],
#          [ 0.06462876,  0.04168192, -0.0015575 , ...,  0.08431154,
#            0.06039558,  0.04677588]],
#
#         [[-0.10445419,  0.0078579 ,  0.06319898, ..., -0.07520504,
#            0.07697699,  0.04410471],
#          [-0.03955499, -0.10629892, -0.00914118, ...,  0.05779906,
#           -0.03605448, -0.08013344],
#          [-0.04188865, -0.0590103 , -0.0938871 , ...,  0.00071486,
#            0.01655809, -0.06627065],
#          ...,
#          [-0.0836831 ,  0.07792092,  0.01548867, ...,  0.04690216,
#           -0.10978185,  0.04044262],
#          [-0.04420311, -0.03658628, -0.08135089, ..., -0.00842968,
#           -0.07887609,  0.03807608],
#          [ 0.0581431 ,  0.00837136, -0.08298326, ..., -0.06392679,
#           -0.0982014 , -0.0742007 ]]],
#
#
#        [[[-0.03635136, -0.08250577,  0.06451362, ..., -0.04043765,
#            0.01271183, -0.07378558],
#          [-0.09514852, -0.06211064,  0.01320066, ..., -0.00358554,
#            0.08433148,  0.01186287],
#          [-0.04717007,  0.01145918, -0.02777289, ...,  0.06519184,
#            0.02048696, -0.10163662],
#          ...,
#          [ 0.0499448 ,  0.06175156,  0.0820456 , ...,  0.00187844,
#           -0.07400806, -0.06529474],
#          [-0.03640702, -0.0038528 ,  0.01085104, ..., -0.03387852,
#           -0.02930424, -0.02116737],
#          [-0.0589606 , -0.05639966,  0.06408313, ...,  0.00243034,
#           -0.11267411, -0.0562622 ]],
#
#         [[-0.06258973,  0.02065471, -0.08384427, ...,  0.05476898,
#           -0.03410861,  0.08015355],
#          [-0.03396607, -0.00346902,  0.05546541, ..., -0.0618827 ,
#            0.0793883 ,  0.01905439],
#          [ 0.01204725, -0.06954674, -0.0858505 , ...,  0.02554325,
#            0.03698494,  0.06423108],
#          ...,
#          [-0.01834162,  0.0375171 , -0.10284784, ..., -0.04964659,
#            0.04738557,  0.05481008],
#          [-0.03348295, -0.00334372, -0.04606426, ..., -0.07237527,
#            0.0913182 , -0.04542706],
#          [-0.04907294,  0.06949952,  0.06976268, ..., -0.04928571,
#            0.00333223, -0.09249992]],
#
#         [[-0.0279708 ,  0.02735211, -0.11523847, ..., -0.03251597,
#           -0.01261778,  0.02634782],
#          [ 0.04105947,  0.02415416, -0.0348875 , ..., -0.01114597,
#            0.08681905,  0.04117237],
#          [ 0.00423951,  0.0004379 ,  0.01526087, ..., -0.04856841,
#           -0.0763548 , -0.00518088],
#          ...,
#          [ 0.02191591, -0.04918482,  0.00772168, ...,  0.01180066,
#           -0.06415455, -0.06702309],
#          [-0.09640791,  0.06876867, -0.00588582, ...,  0.09746064,
#           -0.04410621, -0.04463842],
#          [-0.04868511,  0.09854715,  0.0590247 , ..., -0.01590475,
#           -0.06536985,  0.07710967]]],
#
#
#        [[[-0.0243758 , -0.12777914,  0.01196291, ...,  0.06722829,
#            0.03478985,  0.09369761],
#          [-0.05768177, -0.06927539, -0.0681133 , ...,  0.0240219 ,
#           -0.09822881,  0.0488982 ],
#          [-0.03986275, -0.03679053, -0.06688783, ...,  0.02039658,
#            0.05800435, -0.02917048],
#          ...,
#          [ 0.09083598,  0.01259266,  0.09162698, ..., -0.00211099,
#            0.08292454, -0.06838473],
#          [-0.07824611, -0.10048843, -0.07460395, ..., -0.02593641,
#           -0.01066968,  0.07207681],
#          [-0.06238598, -0.04335953, -0.0219178 , ..., -0.02938498,
#           -0.04979442, -0.07018615]],
#
#         [[-0.00979408, -0.06089417,  0.03031256, ..., -0.00705447,
#           -0.0429541 , -0.10117602],
#          [-0.0950288 , -0.07727051,  0.00821874, ..., -0.08541785,
#            0.00737446,  0.06773681],
#          [ 0.04793102, -0.02963027,  0.07167384, ...,  0.10755587,
#           -0.09177653,  0.05908839],
#          ...,
#          [ 0.04630626,  0.07969662,  0.03694517, ...,  0.01184798,
#           -0.02399299, -0.0114492 ],
#          [ 0.04280545, -0.12598872,  0.01331855, ..., -0.07620747,
#           -0.02719389, -0.09979615],
#          [ 0.10218103,  0.04951398,  0.09004249, ..., -0.03130018,
#            0.04247124,  0.06804337]],
#
#         [[ 0.08173623, -0.08376791,  0.0532407 , ...,  0.03435569,
#            0.02403141,  0.05488843],
#          [ 0.08728936,  0.02021389, -0.00759183, ..., -0.02850241,
#           -0.00480029, -0.02596969],
#          [-0.02672156,  0.07878778, -0.02061363, ..., -0.05978348,
#            0.0631609 , -0.01437423],
#          ...,
#          [ 0.03656942,  0.02248367, -0.0776113 , ...,  0.02514339,
#           -0.03753978, -0.04115414],
#          [-0.05685675, -0.00925137,  0.04780027, ...,  0.06122003,
#            0.03671278,  0.01168787],
#          [-0.02056654, -0.06265236,  0.04776204, ...,  0.01714621,
#           -0.06751243, -0.03880058]]]], dtype=float32)>
# <tf.Variable 'conv2d_52/bias:0' shape=(32,) dtype=float32, numpy=
# array([-0.00880538,  0.0073706 , -0.01391357,  0.00719196, -0.02131142,
#        -0.01532362,  0.00204281, -0.00235552, -0.01809656, -0.01651167,
#        -0.0032158 , -0.01609726,  0.0009688 ,  0.00456677,  0.0022148 ,
#         0.02917751, -0.0329721 ,  0.02296174, -0.01320974, -0.00328677,
#        -0.00226165, -0.01602476, -0.0188144 ,  0.03990952,  0.0108343 ,
#        -0.00678502, -0.00956018,  0.01641276, -0.02161022,  0.01275105,
#         0.01254867, -0.02394775], dtype=float32)>
# <tf.Variable 'conv2d_53/kernel:0' shape=(3, 3, 32, 32) dtype=float32, numpy=
# array([[[[ 0.0005561 , -0.11205621,  0.05477081, ..., -0.07907636,
#           -0.10478564,  0.09426914],
#          [ 0.04876473, -0.06427536,  0.0376017 , ..., -0.05745742,
#            0.0481274 , -0.0028321 ],
#          [-0.09266231,  0.0201316 , -0.04813245, ..., -0.0760714 ,
#            0.01367351, -0.09559275],
#          ...,
#          [ 0.02106033, -0.03874991, -0.02740729, ...,  0.07111017,
#            0.05149457,  0.0757178 ],
#          [ 0.005239  , -0.01940168, -0.01947673, ...,  0.0766359 ,
#            0.0102243 , -0.08024708],
#          [-0.06799654,  0.09850702,  0.08017591, ..., -0.05303676,
#           -0.05399252, -0.10277056]],
#
#         [[ 0.06311927,  0.06450769,  0.02922627, ..., -0.09910707,
#           -0.00760688, -0.00097499],
#          [ 0.01461618, -0.02387557, -0.06706008, ..., -0.04185164,
#           -0.02687054,  0.00157447],
#          [ 0.05829905, -0.10479276, -0.0254477 , ..., -0.00156052,
#           -0.00464374, -0.06842863],
#          ...,
#          [-0.07620045, -0.00411767, -0.11482026, ...,  0.02168112,
#            0.04524704,  0.07547757],
#          [-0.0287991 ,  0.02173336, -0.00090235, ...,  0.04432056,
#            0.06662396,  0.08604951],
#          [-0.06292744,  0.05935857, -0.02534212, ..., -0.07075208,
#           -0.0786741 , -0.04111188]],
#
#         [[ 0.05186404, -0.02412775,  0.04277056, ..., -0.07804541,
#            0.06033513,  0.0903836 ],
#          [-0.04425797, -0.03456128, -0.07874091, ...,  0.00111301,
#           -0.0403489 , -0.05546672],
#          [ 0.0005862 , -0.00241615,  0.03936528, ...,  0.00957052,
#            0.04432062,  0.04609366],
#          ...,
#          [-0.08634435, -0.02287373, -0.04790631, ..., -0.01600734,
#           -0.03570455,  0.03502141],
#          [ 0.00282656,  0.05451686, -0.08003101, ...,  0.0657393 ,
#            0.09259198,  0.01917798],
#          [ 0.11795216,  0.03942874, -0.01638836, ..., -0.04479753,
#           -0.07891668,  0.00911993]]],
#
#
#        [[[-0.03386553, -0.10285216,  0.09747997, ...,  0.07059927,
#            0.01979593,  0.00772358],
#          [ 0.07719757, -0.10406338, -0.05296292, ..., -0.02724079,
#            0.08460721,  0.03819757],
#          [ 0.05511987,  0.07263995,  0.02113709, ...,  0.01357609,
#            0.06654119, -0.05984407],
#          ...,
#          [ 0.04946658, -0.00306211, -0.04648165, ...,  0.01706549,
#           -0.10873219, -0.03139118],
#          [-0.01638259, -0.05422237, -0.02720923, ...,  0.08167963,
#            0.09700738, -0.07060661],
#          [-0.05552932, -0.03035516,  0.07122983, ...,  0.07262024,
#           -0.01771966,  0.08483837]],
#
#         [[ 0.05798759, -0.07786479, -0.05516177, ..., -0.06553933,
#           -0.00519606, -0.08203039],
#          [-0.03616272, -0.03007293, -0.08827445, ..., -0.00885776,
#            0.01132367, -0.02241017],
#          [-0.08644184, -0.00077776, -0.07401316, ..., -0.01460172,
#            0.05796867,  0.08748051],
#          ...,
#          [ 0.01324049, -0.0659688 ,  0.03098771, ..., -0.0653991 ,
#           -0.06635734, -0.04179981],
#          [ 0.01191459, -0.06724576,  0.06177282, ..., -0.06005383,
#           -0.09517902, -0.07373959],
#          [ 0.06293745, -0.04349097,  0.04750381, ..., -0.08537441,
#           -0.0626548 ,  0.07564919]],
#
#         [[ 0.05107914,  0.04977126,  0.00560125, ...,  0.04647426,
#           -0.00572302, -0.09249689],
#          [ 0.02334514, -0.01647843,  0.0420286 , ..., -0.01715039,
#           -0.10334057,  0.05291373],
#          [-0.00309433, -0.00079774, -0.07087166, ..., -0.01612795,
#            0.04620095,  0.03175562],
#          ...,
#          [-0.06174495, -0.00779439, -0.09548093, ..., -0.00416419,
#           -0.10119786, -0.00177804],
#          [ 0.09101065, -0.00786452,  0.02619835, ..., -0.03988947,
#            0.00123423, -0.04634856],
#          [-0.04261524, -0.04944093, -0.02214985, ...,  0.0539196 ,
#            0.00517973, -0.07823262]]],
#
#
#        [[[ 0.0863129 , -0.01721711,  0.0446181 , ..., -0.00389541,
#            0.01732883, -0.05786683],
#          [ 0.00131136, -0.07127851,  0.02885687, ...,  0.04696928,
#           -0.04367589, -0.08441605],
#          [ 0.04177675,  0.08129676,  0.09387354, ...,  0.06600896,
#           -0.01509775, -0.04314622],
#          ...,
#          [ 0.01493824,  0.07855035, -0.00834261, ..., -0.10958605,
#           -0.02442503, -0.05274446],
#          [ 0.09634298, -0.02225873,  0.01807377, ...,  0.04818823,
#            0.01086093, -0.02597632],
#          [-0.02457354, -0.04310134,  0.02635623, ..., -0.03732236,
#            0.0345354 , -0.06415118]],
#
#         [[ 0.04816888, -0.0094537 , -0.06725498, ..., -0.0672264 ,
#            0.0663024 ,  0.06130587],
#          [-0.0841167 , -0.00366758, -0.08126602, ..., -0.07976203,
#           -0.06148295, -0.07868337],
#          [ 0.10464083, -0.03552751,  0.00772278, ..., -0.00810171,
#            0.02804348,  0.06879911],
#          ...,
#          [ 0.01031847, -0.07089493, -0.03128821, ...,  0.06087933,
#           -0.0871123 ,  0.03799249],
#          [-0.01835105, -0.02957945, -0.01894474, ..., -0.00735696,
#           -0.00042825, -0.0221508 ],
#          [ 0.03534428,  0.06629849,  0.04288667, ...,  0.00581755,
#           -0.06095516, -0.06128797]],
#
#         [[-0.09135842, -0.00489569,  0.00693327, ...,  0.02605079,
#            0.09565869, -0.04465887],
#          [-0.01864657,  0.02984053,  0.0728905 , ...,  0.01794169,
#           -0.04590675, -0.00897584],
#          [-0.02303767, -0.00238473, -0.08641686, ...,  0.03415439,
#            0.05064736, -0.02042214],
#          ...,
#          [-0.10386214,  0.03290454,  0.07677095, ...,  0.02465764,
#           -0.10316692,  0.05819584],
#          [-0.08659136,  0.0273436 ,  0.06216835, ..., -0.09518563,
#           -0.04976308, -0.05633795],
#          [ 0.02585397,  0.07704549,  0.05458729, ...,  0.0265913 ,
#           -0.00638123, -0.02079925]]]], dtype=float32)>
# <tf.Variable 'conv2d_53/bias:0' shape=(32,) dtype=float32, numpy=
# array([-0.00043764, -0.03833225, -0.00631115,  0.0048401 , -0.02785064,
#        -0.01401887, -0.02903758, -0.01590444, -0.01940926,  0.00387366,
#        -0.02138616, -0.00402766,  0.00573217, -0.0193344 , -0.02216399,
#        -0.02515662, -0.00177754,  0.00284597,  0.00898963,  0.00053894,
#        -0.03094555,  0.00284847,  0.00181352, -0.01822773,  0.00820494,
#         0.00599649, -0.02344805, -0.00538181,  0.01534976, -0.01639341,
#        -0.0159458 , -0.02897632], dtype=float32)>
# <tf.Variable 'conv2d_54/kernel:0' shape=(3, 3, 32, 64) dtype=float32, numpy=
# array([[[[ 0.00427672, -0.01237959,  0.0305774 , ...,  0.00329446,
#           -0.0156892 , -0.07735738],
#          [-0.02334836, -0.05381806,  0.04853867, ...,  0.03093988,
#            0.00590141,  0.05331608],
#          [ 0.05926833, -0.08240911, -0.05394792, ..., -0.08214074,
#           -0.04945555,  0.08137856],
#          ...,
#          [-0.01089699,  0.04193358, -0.01495236, ...,  0.06159145,
#            0.03941272, -0.04881153],
#          [ 0.02751352, -0.06723218,  0.03228529, ...,  0.0206283 ,
#            0.05268658,  0.08331247],
#          [ 0.05648804, -0.01359048, -0.02090634, ..., -0.00436907,
#            0.07984862, -0.05846407]],
#
#         [[ 0.06500266,  0.05295887, -0.07308115, ..., -0.06257164,
#           -0.01815075,  0.05844504],
#          [ 0.06980017, -0.03358433, -0.04013156, ...,  0.05281629,
#            0.01994147, -0.00160011],
#          [-0.0725657 , -0.01172948, -0.01614567, ..., -0.04170315,
#           -0.06775434,  0.00358799],
#          ...,
#          [ 0.04413439,  0.08131015, -0.00444407, ...,  0.00955398,
#            0.00481247,  0.02067592],
#          [ 0.06121495, -0.0228968 ,  0.07006668, ...,  0.0430588 ,
#           -0.06629661,  0.07697304],
#          [-0.07930787, -0.07222681,  0.07628878, ..., -0.08356457,
#            0.05305683,  0.04702408]],
#
#         [[-0.07468682,  0.06149414, -0.02287334, ..., -0.0453541 ,
#           -0.06793072,  0.08399235],
#          [ 0.05010264, -0.02099599, -0.02333754, ...,  0.05035719,
#            0.0014895 , -0.0487072 ],
#          [-0.07193395,  0.01541706, -0.03963831, ..., -0.07182141,
#            0.07247019, -0.03983144],
#          ...,
#          [-0.00913555, -0.02040466,  0.06491701, ...,  0.01240569,
#            0.01245534,  0.05999127],
#          [-0.0498459 ,  0.08266805, -0.03004188, ...,  0.03650026,
#           -0.02123577,  0.04545642],
#          [-0.07286927,  0.00775141,  0.04966506, ..., -0.07997125,
#            0.02286239,  0.02673847]]],
#
#
#        [[[-0.0131946 ,  0.08321323, -0.02371343, ...,  0.07578421,
#            0.03710505, -0.0520507 ],
#          [ 0.00894752, -0.02206635, -0.04673792, ...,  0.00635704,
#           -0.00375887, -0.021908  ],
#          [-0.05188845,  0.04175866,  0.00915273, ..., -0.01614568,
#            0.02497543, -0.02665566],
#          ...,
#          [ 0.07470225, -0.07252561,  0.03984263, ..., -0.04504256,
#            0.06337903,  0.03368203],
#          [ 0.00922384, -0.07214323,  0.05202602, ..., -0.05114292,
#           -0.02472074, -0.01934794],
#          [ 0.07954565,  0.01434789, -0.04204611, ...,  0.017075  ,
#           -0.03161086,  0.03511254]],
#
#         [[-0.09286795,  0.03020678, -0.0071733 , ..., -0.05063719,
#           -0.02465565,  0.01162254],
#          [ 0.00383755,  0.01114703, -0.02773689, ...,  0.01013179,
#            0.08396864,  0.04204928],
#          [ 0.0371671 ,  0.00353817, -0.03322023, ..., -0.02913183,
#           -0.00875041,  0.01101139],
#          ...,
#          [-0.08088414,  0.06002019, -0.03329365, ...,  0.01507832,
#           -0.05584409,  0.04215898],
#          [ 0.00842385,  0.00189213, -0.03840509, ...,  0.00306529,
#           -0.03733694,  0.00330277],
#          [-0.01284367,  0.04240591,  0.01351423, ..., -0.06371587,
#            0.03759998,  0.02993507]],
#
#         [[-0.01652662, -0.03592117, -0.01681955, ...,  0.02015771,
#            0.04414473, -0.08469969],
#          [-0.03881259,  0.02289262, -0.04136981, ...,  0.02239292,
#            0.00645739,  0.03031485],
#          [-0.02161214, -0.02866627, -0.08048654, ..., -0.0231321 ,
#           -0.07721755, -0.04362097],
#          ...,
#          [-0.08158825,  0.06804813, -0.03273693, ..., -0.02298297,
#            0.04859923,  0.00023143],
#          [-0.07413668,  0.08154836, -0.01237352, ...,  0.04680682,
#           -0.04542198, -0.08524204],
#          [-0.02183506,  0.05250962, -0.08864158, ...,  0.07466848,
# ...
#         0.02181092,  0.02165367,  0.0216586 ,  0.00039817,  0.01855735,
#         0.00824737, -0.01276713, -0.02277245, -0.00718364, -0.02319136,
#         0.0258257 , -0.02903902,  0.00052536, -0.01740401,  0.00585217,
#        -0.00504321, -0.00152464, -0.00438915, -0.01327167, -0.00089589,
#         0.00264805,  0.01741434,  0.01533107, -0.0130918 ], dtype=float32)>
# <tf.Variable 'conv2d_55/kernel:0' shape=(3, 3, 64, 64) dtype=float32, numpy=
# array([[[[-0.01576431, -0.00715342,  0.01007552, ..., -0.06923823,
#           -0.06814906, -0.03710176],
#          [ 0.07089439,  0.01502625, -0.03211357, ...,  0.01766431,
#            0.0073417 ,  0.01364141],
#          [-0.0383568 ,  0.05066295, -0.076196  , ...,  0.06018821,
#           -0.01029822,  0.05264991],
#          ...,
#          [ 0.03227599, -0.04448117, -0.04016234, ..., -0.03116904,
#           -0.05901263, -0.00926848],
#          [ 0.02665989,  0.01384812, -0.05621988, ..., -0.01890095,
#            0.02284331,  0.01840245],
#          [-0.03114076,  0.06968544,  0.02094746, ..., -0.0389178 ,
#            0.02280497,  0.07075613]],
#
#         [[ 0.05461116, -0.0227589 ,  0.04571904, ..., -0.05874717,
#            0.03763421, -0.06991549],
#          [ 0.06194815,  0.01692334,  0.00797557, ...,  0.038945  ,
#           -0.05654056, -0.07775673],
#          [ 0.04347395, -0.05107499,  0.04396233, ...,  0.03349893,
#            0.00952591, -0.02595405],
#          ...,
#          [ 0.02482397, -0.04417453, -0.04351027, ...,  0.02372261,
#           -0.04867871,  0.05554556],
#          [-0.02177257, -0.05126413,  0.03174771, ...,  0.00479072,
#           -0.02269136,  0.05152839],
#          [-0.05683691, -0.02259698, -0.08011968, ..., -0.06676304,
#            0.02485298, -0.00791107]],
#
#         [[-0.05953226,  0.02924667,  0.03257364, ..., -0.00879622,
#           -0.03780387, -0.06297438],
#          [ 0.05507461, -0.04800681, -0.01050389, ...,  0.04430321,
#           -0.01395708, -0.02512719],
#          [ 0.05632878, -0.06765096,  0.02217253, ...,  0.05792797,
#            0.05519837, -0.06447063],
#          ...,
#          [-0.04169032,  0.01317027, -0.07186731, ...,  0.07551382,
#            0.04626349,  0.06924903],
#          [-0.05473978,  0.01678021,  0.03973326, ...,  0.03590242,
#           -0.0687133 ,  0.0556747 ],
#          [-0.03464562,  0.04526858, -0.04118708, ..., -0.04531102,
#            0.02276115, -0.07454982]]],
#
#
#        [[[ 0.06499512, -0.02217246,  0.00752323, ...,  0.00997686,
#            0.00299264, -0.03242518],
#          [-0.04561958,  0.06257863, -0.05217973, ..., -0.05135321,
#            0.06295228, -0.07467799],
#          [ 0.03493975, -0.07353199, -0.07378145, ...,  0.0057818 ,
#           -0.00137582,  0.05054218],
#          ...,
#          [ 0.07201787, -0.02931485, -0.03494627, ..., -0.06610707,
#           -0.06228286, -0.04717081],
#          [ 0.02958563, -0.07319425, -0.01756059, ...,  0.06059219,
#           -0.08017229,  0.02778841],
#          [-0.0155484 , -0.02068784, -0.01411512, ...,  0.01651114,
#           -0.00338736, -0.04299762]],
#
#         [[-0.05605549, -0.00407035,  0.06148499, ..., -0.02585039,
#            0.02093523,  0.05236613],
#          [-0.06074265,  0.00015607,  0.00663941, ...,  0.05583202,
#            0.03711645,  0.05307219],
#          [ 0.06169654,  0.04849162,  0.06155497, ..., -0.02695398,
#           -0.04066375,  0.01783673],
#          ...,
#          [-0.05541006,  0.0113928 , -0.06904016, ..., -0.04872433,
#            0.06563184, -0.02831599],
#          [-0.07065628,  0.05702019,  0.007145  , ..., -0.01491338,
#           -0.08310662, -0.06685439],
#          [ 0.00814677,  0.00464736,  0.03459171, ..., -0.00631147,
#           -0.04698042,  0.00840584]],
#
#         [[-0.04464312,  0.03122744,  0.02147638, ...,  0.03238316,
#            0.05206334, -0.06118529],
#          [ 0.03971918,  0.05119648, -0.03960359, ..., -0.04202979,
#            0.01679312,  0.03643046],
#          [-0.02835411,  0.01606004, -0.02611175, ..., -0.04846212,
#           -0.01432644, -0.04393396],
#          ...,
#          [ 0.06940422, -0.0534797 , -0.04463716, ...,  0.0669153 ,
#            0.01528652, -0.05865806],
#          [-0.06692992,  0.05426602,  0.04210487, ...,  0.01350139,
#           -0.05616882, -0.05352891],
#          [ 0.07020257,  0.05875646,  0.03810579, ..., -0.0114294 ,
#           -0.00637165,  0.01505813]]],
#
#
#        [[[ 0.03489088, -0.03495313,  0.01127715, ..., -0.04860689,
#           -0.00659889,  0.0183181 ],
#          [-0.01471353,  0.07386029,  0.04951806, ...,  0.01896606,
#            0.03393824, -0.06941402],
#          [ 0.05072045, -0.00188655, -0.00914343, ..., -0.07523351,
#            0.01153613, -0.06819642],
#          ...,
#          [-0.07414643,  0.05130892,  0.00081383, ..., -0.04347244,
#           -0.05009226,  0.07437386],
#          [ 0.06742723, -0.06204442,  0.02430609, ...,  0.04003038,
#           -0.01459186,  0.00856294],
#          [-0.04247404,  0.06670664,  0.00115809, ...,  0.00624302,
#            0.05810409, -0.02857503]],
#
#         [[-0.03350487, -0.0529368 ,  0.05338088, ..., -0.0106009 ,
#           -0.00270037, -0.02503605],
#          [-0.03599638, -0.04481242, -0.02821361, ..., -0.02405429,
#           -0.00831311, -0.03265456],
#          [-0.03012246,  0.00306823,  0.0069253 , ..., -0.01467854,
#            0.00371831,  0.05159293],
#          ...,
#          [-0.08132985,  0.03707715,  0.04921503, ...,  0.04866642,
#           -0.00264775, -0.04550668],
#          [ 0.02133427,  0.03096148,  0.02021047, ...,  0.03292031,
#           -0.03935087,  0.04378726],
#          [-0.06698407, -0.05133833,  0.07354093, ...,  0.00412179,
#           -0.04842066, -0.01604985]],
#
#         [[ 0.03931155, -0.00038783,  0.06545742, ...,  0.02831051,
#           -0.00685541, -0.01916021],
#          [ 0.00774706, -0.01532065, -0.04860786, ..., -0.04973162,
#           -0.03089762,  0.04198472],
#          [-0.00580283,  0.02390287,  0.0296647 , ...,  0.04051436,
#            0.01746037, -0.01817102],
#          ...,
#          [-0.02300614, -0.01625183,  0.00048744, ...,  0.05719971,
#            0.04150955, -0.01200748],
#          [-0.06623203, -0.04927284,  0.0338545 , ..., -0.03514683,
#            0.00614728, -0.03763689],
#          [ 0.03216555, -0.05546466, -0.02731951, ...,  0.03478565,
#            0.03138796, -0.04478467]]]], dtype=float32)>
# <tf.Variable 'conv2d_55/bias:0' shape=(64,) dtype=float32, numpy=
# array([ 0.01047788, -0.02640365, -0.02548708, -0.00466258, -0.02791275,
#        -0.02110069, -0.02721214, -0.02511099, -0.02528845,  0.00080753,
#        -0.02724987, -0.02923992,  0.01368784, -0.0251249 , -0.02760502,
#        -0.00789035, -0.00632733, -0.02672776, -0.01578679, -0.01616675,
#         0.00477794, -0.02291935, -0.02126268,  0.00271021, -0.01747648,
#        -0.01156009, -0.00767241,  0.0076643 , -0.02260475, -0.02211404,
#         0.00055628,  0.01335374, -0.01969579, -0.00624923, -0.01320409,
#        -0.01478713,  0.00722385,  0.00142341,  0.01176828,  0.0060089 ,
#         0.01950853, -0.01684572, -0.01537334, -0.01933256, -0.02374197,
#        -0.01383825, -0.01839046], dtype=float32)>
# <tf.Variable 'dense_15/kernel:0' shape=(512, 2) dtype=float32, numpy=
# array([[-0.03267532, -0.05246285],
#        [ 0.06640425,  0.08901019],
#        [-0.03992454,  0.05556894],
#        ...,
#        [-0.00567506, -0.04721241],
#        [ 0.04384675, -0.02584514],
#        [-0.0260343 , -0.10353104]], dtype=float32)>
# <tf.Variable 'dense_15/bias:0' shape=(2,) dtype=float32, numpy=array([-0.02748923,  0.02748903], dtype=float32)>

# %% [markdown]
# Unfortunately, that probably didn’t help you make a useful explanation.
#
# Researchers are currently studying ways to make neural networks more explainable. One approach is using **saliency maps** to figure out the saliency (importance) of each individual pixel. Check out a demo [here](https://lrpserver.hhi.fraunhofer.de/image-classification). Intuitively, we're trying to understand the neural network by tracking what it "pays attention" to, in the same way that psychologists study babies' cognition by [tracking what babies look at](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3259733/).
#
# In this exercise, we're going to build a simple version of a saliency map for the image you chose above. We'll see what pixels were most important in helping the network make its classification.
#
# To do this, we'll investigate the effects of changing each pixel a little bit. If changing a particular pixel changes the result a lot, we conclude that pixel must be important for classifying. If changing that pixel doesn't change the result, we conclude that pixel is unimportant.

# %% [markdown]
# We're going to use the raw predicted probabilities, rather than the final classification.

# %%
pred = cnn.predict_proba(np.array([input_image])) #What does each number mean?
print (pred)
dog_prob = pred[0][0] #This is the probability we'll use (if we know dog prob, we know the classification)

print ('Probability of dog:')
print (dog_prob)
# Out:
# [[1.000000e+00 2.170039e-24]]
# Probability of dog:
# 1.0

# %% [markdown]
# **Now**, we need to calculate the saliency for each pixel (really, each R/G/B value). The core idea is that a pixel's saliency is the average value of
#
#  $D = |\frac{\Delta probability}{\Delta pixel}|$
#
#  where $\Delta$ is the amount of change. If a small change in the pixel value results in a large change in the probability (either up or down), we know this pixel is important. If you've seen derivatives in calculus, this idea should feel familiar.
#
# Here's the game plan:
#
# *   Consider each pixel value in turn: R, G, B, then the next pixel.
# *   Make a copy of the image array before you change anything!
# *   Make the pixel value larger or smaller by various amounts. Each time, find the CNN's prediction with the changed value, and calculate the value of D.
# *   Repeat the previous step a few times, and calculate the pixel's saliency: the average value of D.
# *   Store the saliency of each pixel in a list, so that we can visualize it later.
#
# Try it below! (Warning: this code might be very slow. As a further challenge, try to speed it up!)

# %%
saliencies = [] #eventually, will be the same size as input_image

for index, pixel in enumerate(input_image):
  #index counts up from 0, pixel is between 0 and 255
  
  if index%100 == 0: #will track progress - this might take a while
    print (index)
  
  changed_input = input_image.copy() #make sure not to change the original input_image!
  
  #YOUR CODE HERE:
  #In changed_input, change the value of this pixel by some amount.
  #Use the CNN to classify changed_input.
  #Calculate the value of D.
-05, 5.244990189870198e-05, 5.8869202931722e-05, 5.887683232625326e-05, 5.254798465304905e-05, 5.893182754516602e-05, 5.888589223225912e-05, 5.8868090311686196e-05, 5.879656473795574e-05, 5.886205037434895e-05, 5.881039301554361e-05, 5.89280128479004e-05, 5.879433949788412e-05, 5.240208572811551e-05, 5.2421821488274464e-05, 5.2394270896911626e-05, 5.242837799919976e-05, 5.2470101250542534e-05, 5.244606071048313e-05, 5.2261286311679416e-05, 5.2430033683776855e-05, 5.234956741333008e-05, 5.218154854244656e-05, 5.232797728644477e-05, 5.225996176401774e-05, 5.2349501185946995e-05, 5.227049191792806e-05, 5.237076017591688e-05, 5.232632160186767e-05, 5.235844188266331e-05, 5.2382018831041125e-05, 5.220863554212783e-05, 5.237506495581733e-05, 5.240625805324979e-05, 5.874427159627279e-05, 6.494144598642986e-05, 6.488998730977377e-05, 5.248586336771647e-05, 5.8684428532918294e-05, 5.8722654978434246e-05, 5.253679222530789e-05, 5.253109667036269e-05, 5.8717409769694014e-05, 5.26766644583808e-05, 5.254440837436252e-05, 5.892165501912435e-05, 5.8939139048258475e-05, 5.916563669840494e-05, 5.91127872467041e-05, 5.870159467061361e-05, 5.267851882510715e-05, 5.261911286248101e-05, 5.234585867987739e-05, 5.276951524946425e-05, 5.253705713484022e-05, 5.2557256486680776e-05, 5.261401335398356e-05, 5.2669644355773924e-05, 5.889987945556641e-05, 5.2560567855834964e-05, 5.24906317392985e-05, 5.125297440422905e-05, 6.467491388320923e-05, 6.485541661580403e-05, 5.237943596310087e-05, 5.2412019835578064e-05, 5.2532951037089024e-05, 5.2454935179816354e-05, 5.251599682701958e-05, 5.242811308966743e-05, 5.240321159362792e-05, 5.235513 ...

# %% [markdown]
# You'll notice that your saliencies are probably very small values, since each individual pixel has a small effect on the output.
# Here are the current min and max:

# %%
sal_array = np.array(saliencies)
print (sal_array.min(), sal_array.max())
print (sal_array.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-14ed46c07ef2> in <module>
# ----> 1 sal_array = np.array(saliencies)
#       2 print (sal_array.min(), sal_array.max())
#       3 print (sal_array.shape)
#
# NameError: name 'np' is not defined

# %% [markdown]
# To plot the saliencies, we need to do some arithmetic to transform them to a range of 0 to 1. Can you explain the function of each line?

# %%
sal_array = np.array(saliencies)
sal_array = sal_array - sal_array.min()
#TODO print min and max

sal_array = sal_array/sal_array.max()
#TODO print min and max

#Can you perform this transformation in a single line of code?

print (sal_array.shape)

# %% [markdown]
# Finally, we can plot our saliency map!
#
# If you're not getting great results, try experimenting with how much you're changing the pixel values.

# %%
#Plot our original image
plt.imshow(input_image.reshape(32,32,3).astype(int))
plt.show()

#Plot our saliency map: the brighter, the higher the saliency
plt.imshow(sal_array.reshape(32,32,3))
plt.show()

#Plot our saliency map superimposed on the image
plt.imshow(input_image.reshape(32,32,3).astype(int))
plt.imshow(sal_array.reshape(32,32,3),alpha=0.6)
plt.show()

# %% [markdown]
# We now have some insight into our neural network! We know which pixels matter in its decisions.
#
# You can experiment with the definition of saliency we used above; you might come up with a better way to measure it!
